# %%
import numpy as np
from newsapi import NewsApiClient
import spacy
import tweepy
import datetime as dt
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from time import sleep
import pymongo
from bson.son import SON
from bson import json_util
from pprint import pprint
# Out:
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192, got 176
#   return f(*args, **kwds)

# %%
# Init
newsapi = NewsApiClient(api_key='797cf54cbf3749e8b5954167579f7929')

# # /v2/top-headlines
# top_headlines = newsapi.get_top_headlines(q='bitcoin',
#                                           sources='bbc-news,the-verge',
#                                           category='business',
#                                           language='en',
#                                           country='us')

# # /v2/everything
# all_articles = newsapi.get_everything(q='bitcoin',
#                                       sources='bbc-news,the-verge',
#                                       domains='bbc.co.uk,techcrunch.com',
#                                       from_param='2017-12-01',
#                                       to='2017-12-12',
#                                       language='en',
#                                       sort_by='relevancy',
#                                       page=2)

# # /v2/sources
# sources = newsapi.get_sources()

# %%
nlp = spacy.load('en')

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.project_reax

# %%
# db.inventory.find( { tags: { $all: ["red", "blank"] } } )
# documents =  db.reddit_city.find({}, {'datetime': str(dt.datetime.now().strftime('%Y-%m-%d'))}).sort('title')
documents =  db.reddit_state.find({'datetime': dt.datetime.now().strftime('%Y-%m-%d')}).sort('commment_dict')

# %%
sents = {"sentiments": []}
for i,d in enumerate(documents):
    print(i)
    keys = d['keys']
    values = d['values']
    location = d['location']
    print(location)
    vaderholder = []
    stateholder = ""
    

#     sentdict['state'].append(location)
    try:
        for x in range(len(d['comment_dict'])):
            
            statered = d['comment_dict'][x]['subreddit']
            state = statered.split('/')[1]
          
            #only want to add state once, but the others multiple times
            
            if (location == state) and (x == 0):
                stateholder = state
                vaderholder.append(d['comment_dict'][x]['vader']['compound'])
                
            elif (location == state):
                vaderholder.append(d['comment_dict'][x]['vader']['compound'])                
            else:
                pass
        
        if (len(vaderholder) > 0):
            compoundavg = np.mean(vaderholder)
            print(compoundavg)
#             location = stateholder[0]
#             sentdict['location'].append(location)
#             sentdict['compound'].append(compoundavg)
            sents['sentiments'].append(dict(zip(stateholder, vaderholder)))
        else:
            pass

#     sentiments['sentiments'].append(dict(zip(stateholder, vaderholder)))
                
        
    except IndexError:
        bad_i.append(i)
# Out:
# 0
# Alabama
# 0.25795
# 1
# alaska
# 0.3545111111111111
# 2
# alaska
# 0.19186666666666666
# 3
# alaska
# 0.20175
# 4
# alaska
# 5
# alaska
# 6
# alaska
# 0.0
# 7
# alaska
# 8
# alaska
# -0.9239
# 9
# alaska
# 10
# alaska
# 0.0
# 11
# alaska
# 12
# alaska
# 0.0
# 13
# alaska
# 14
# alaska
# 0.45155
# 15
# alaska
# 0.3713
# 16
# arizona
# 0.4304125
# 17
# arizona
# 18
# arizona
# -0.26048
# 19
# arizona
# 0.5651666666666667
# 20
# arizona
# 0.0
# 21
# Arkansas
# -0.08895
# 22
# California
# 0.12082000000000001
# 23
# California
# 0.294625
# 24
# California
# 0.18984285714285712
# 25
# California
# 0.12705714285714284
# 26
# California
# -0.220175
# 308
# Tennessee
# -0.08833333333333333
# 309
# Tennessee
# 0.2942
# 310
# Tennessee
# 0.839
# 311
# texas
# -0.0030846153846153736
# 312
# texas
# 0.22565806451612905
# 313
# texas
# 0.21526250000000002
# 314
# texas
# 0.55696
# 315
# texas
# 0.8154199999999999
# 316
# texas
# 0.28975
# 317
# texas
# -0.19579999999999997
# 318
# texas
# -0.2621
# 319
# texas
# -0.2605
# 320
# texas
# 0.22392222222222222
# 321
# texas
# 322
# texas
# -0.37495
# 323
# texas
# 0.2294
# 324
# texas
# 325
# texas
# 0.13406666666666667
# 326
# texas
# -0.2621
# 327
# texas
# 328
# texas
# 0.3711333333333333
# 329
# texas
# 0.0
# 330
# texas
# -0.2621
# 331
# texas
# 0.0
# 332
# texas
# 0.8505
# 333
# texas
# 334
# texas
# 0.06263333333333332
# 335
# texas
# -0.7222000000000001
# 336
# Utah
# 0.82575
# 337
# Utah
# 0.2091
# 338
# Utah
# 339
# Utah
# 0.19134
# 340
# Utah
# 341
# Utah
# 0.594
# 342
# Utah
# -0.070775
# 343
# Utah
# 344
# Utah
# -0.07395
# 345
# vermont
# 0.68194
# 346
# vermont
# 0.1055
# 347
# vermont
# 348
# vermont
# 349
# vermont
# 350
# vermont
# 351
# vermont
# 352
# vermont
# 353
# vermont
# 0.10072499999999998
# 354
# vermont
# 355
# vermont
# 0.185225
# 356
# Virginia
# -0.33419999999999994
# 357
# Virginia
# -0.09206
# 358
# Virginia
# 0.0
# 359
# Virginia
# -0.05135
# 360
# Virginia
# 0.3478333333333334
# 361
# Virginia
# 0.0
# 362
# Virginia
# 0.6715500000000001
# 363
# Virginia
# 364
# Washington
# 0.5065000000000001
# 365
# Washington
# 0.0
# 366
# WestVirginia
# -0.12726666666666667
# 367
# WestVirginia
# -0.5574
# 368
# WestVirginia
# 369
# WestVirginia
# -0.7845
# 370
# WestVirginia
# 371
# wisconsin
# 0.0602
# 372
# wisconsin
# -0.42006666666666664
# 373
# wisconsin
# 0.27340000000000003
# 374
# wisconsin
# -0.47325
# 375
# wisconsin
# 376
# wisconsin
# 0.0
# 377
# wisconsin
# -0.44295
# 378
# wisconsin
# 0.6751
# 379
# wisconsin
# 380
# wisconsin
# 381
# wisconsin
# 0.3612
# 382
# wyoming
# 0.0874
# 383
# wyoming
# 0.14049999999999999

# %%
print(sents)
# Out:
# {'sentiments': [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]}

# %%
pipeline = [
    {"$unwind": "$comment_dict"},
        {
            "$group":
            {"_id": "$subreddit",
                "avgAmount":{"$avg": "$vader.compound"}
        }
    }
]

# %%
state_vader_agg = db.reddit_state.aggregate(pipeline)

# %%
for state in state_vader_agg:
    pprint(state)
# Out:
# {'_id': None, 'avgAmount': None}

# %%
now = dt.datetime.now().strftime('%Y-%m-%d')
all_articles = newsapi.get_everything(q='stan lee',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param= now,
                                      language='en',
                                      sort_by='relevancy',
                                      page=1)

# %%
all_articles

# %%
sources = newsapi.get_sources()

# %%
sources

# %%
ss = sources['sources']

# %%
possible_sources = []
for s in ss:
    if (s['country'] == 'us'):
        sourcelist = s['id']
        possible_sources.append(sourcelist)

# %%
print(len(possible_sources))

# %%
possible_sources
