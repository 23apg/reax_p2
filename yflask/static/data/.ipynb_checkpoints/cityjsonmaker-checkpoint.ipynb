# %%
import json
from pprint import pprint
import numpy as np
import datetime as dt
import pymongo
import pandas as pd

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.project_reax

# %%
docs = db.city_full_lite.find({})

# %%
holder = []

for d in docs:
    citycity = d['city']
    city = citycity.replace(' ', '')
    latlong = [d['latitude'], d['longitude']]
    
    cityll = {'city' : citycity,
              'll' : latlong,
             }
    holder.append(cityll)

# %%
holder
# Out:
# [{'city': 'New York', 'll': [40.7127837, -74.0059413]},
#  {'city': 'Los Angeles', 'll': [34.0522342, -118.2436849]},
#  {'city': 'Chicago', 'll': [41.8781136, -87.6297982]},
#  {'city': 'Houston', 'll': [29.7604267, -95.3698028]},
#  {'city': 'Philadelphia', 'll': [39.9525839, -75.1652215]},
#  {'city': 'Phoenix', 'll': [33.4483771, -112.0740373]},
#  {'city': 'San Antonio', 'll': [29.4241219, -98.49362819999999]},
#  {'city': 'San Diego', 'll': [32.715738, -117.1610838]},
#  {'city': 'Dallas', 'll': [32.7766642, -96.79698789999999]},
#  {'city': 'San Jose', 'll': [37.3382082, -121.8863286]},
#  {'city': 'Austin', 'll': [30.267153, -97.7430608]},
#  {'city': 'Indianapolis', 'll': [39.768403, -86.158068]},
#  {'city': 'Jacksonville', 'll': [30.3321838, -81.65565099999999]},
#  {'city': 'San Francisco', 'll': [37.7749295, -122.4194155]},
#  {'city': 'Columbus', 'll': [39.9611755, -82.99879419999999]},
#  {'city': 'Charlotte', 'll': [35.2270869, -80.8431267]},
#  {'city': 'Fort Worth', 'll': [32.7554883, -97.3307658]},
#  {'city': 'Detroit', 'll': [42.331427, -83.0457538]},
#  {'city': 'El Paso', 'll': [31.7775757, -106.4424559]},
#  {'city': 'Memphis', 'll': [35.1495343, -90.0489801]},
#  {'city': 'Seattle', 'll': [47.6062095, -122.3320708]},
#  {'city': 'Denver', 'll': [39.7392358, -104.990251]},
#  {'city': 'Washington', 'll': [38.9071923, -77.0368707]},
#  {'city': 'Boston', 'll': [42.3600825, -71.0588801]},
#  {'city': 'Baltimore', 'll': [39.2903848, -76.6121893]},
#  {'city': 'Oklahoma City', 'll': [35.4675602, -97.5164276]},
#  {'city': 'Portland', 'll': [45.5230622, -122.6764816]},
#  {'city': 'Las Vegas', 'll': [36.1699412, -115.1398296]},
#  {'city': 'Milwaukee', 'll': [43.0389025, -87.9064736]},
#  {'city': 'Albuquerque', 'll': [35.0853336, -106.6055534]},
#  {'city': 'Tucson', 'll': [32.2217429, -110.926479]},
#  {'city': 'Fresno', 'll': [36.7468422, -119.7725868]},
#  {'city': 'Sacramento', 'll': [38.5815719, -121.4943996]},
#  {'city': 'Long Beach', 'll': [33.7700504, -118.1937395]},
#  {'city': 'Kansas City', 'll': [39.0997265, -94.5785667]},
#  {'city': 'Mesa', 'll': [33.4151843, -111.8314724]},
#  {'city': 'Virginia Beach', 'll': [36.8529263, -75.97798499999999]},
#  {'city': 'Atlanta', 'll': [33.7489954, -84.3879824]},
#  {'city': 'Colorado Springs', 'll': [38.8338816, -104.8213634]},
#  {'city': 'Omaha', 'll': [41.2523634, -95.99798829999999]},
#  {'city': 'Westminster', 'll': [33.7513419, -117.9939921]},
#  {'city': 'Norwalk', 'll': [41.11774399999999, -73.4081575]},
#  {'city': 'Concord', 'll': [35.4087517, -80.579511]},
#  {'city': 'Lakewood', 'll': [33.8536269, -118.1339563]},
#  {'city': 'Fayetteville', 'll': [36.0625795, -94.1574263]},
#  {'city': 'Wilmington', 'll': [39.7390721, -75.5397878]},
#  {'city': 'Lafayette', 'll': [40.4167022, -86.87528689999999]},
#  {'city': 'Jacksonville', 'll': [34.7540524, -77.4302414]},
#  {'city': 'Jackson', 'll': [35.6145169, -88.81394689999999]},
#  {'city': 'Portland', 'll': [43.66147100000001, -70.2553259]},
#  {'city': 'Springfield', 'll': [44.0462362, -123.0220289]},
#  {'city': 'Springfield', 'll': [39.9242266, -83.8088171]},
#  {'city': 'Lancaster', 'll': [40.0378755, -76.3055144]},
#  {'city': 'Lakewood', 'll': [47.1717649, -122.518458]},
#  {'city': 'Bellevue', 'll': [41.1543623, -95.9145568]},
#  {'city': 'Lakewood', 'll': [41.4819932, -81.7981908]},
#  {'city': 'Charleston', 'll': [38.3498195, -81.6326234]},
#  {'city': 'Alexandria', 'll': [31.3112936, -92.4451371]},
#  {'city': 'Newark', 'll': [40.0581205, -82.4012642]},
#  {'city': 'Roseville', 'll': [42.4972583, -82.9371409]},
#  {'city': 'Madison', 'll': [34.6992579, -86.74833180000002]},
#  {'city': 'Columbus', 'll': [39.2014404, -85.9213796]},
#  {'city': 'Lincoln', 'll': [38.891565, -121.2930079]},
#  {'city': 'Newark', 'll': [37.5296593, -122.0402399]},
#  {'city': 'Cleveland', 'll': [35.1595182, -84.8766115]},
#  {'city': 'Fairfield', 'll': [39.3454673, -84.5603187]},
#  {'city': 'Salem', 'll': [42.51954, -70.8967155]},
#  {'city': 'Concord', 'll': [43.2081366, -71.5375718]},
#  {'city': 'Midland', 'll': [43.6155825, -84.2472116]},
#  {'city': 'Warren', 'll': [41.2375569, -80.81841659999999]},
#  {'city': 'Beaumont', 'll': [33.9294606, -116.977248]},
#  {'city': 'Huntsville', 'll': [30.7235263, -95.55077709999999]},
#  {'city': 'Lancaster', 'll': [39.7136754, -82.5993294]},
#  {'city': 'Lancaster', 'll': [32.5920798, -96.7561082]}]

# %%
reddocs = db.city_simple2.find({})

# %%
empty = []
cities = []


for r in reddocs:
    rcity = r['location']
    rclowernospace = rcity.lower().replace(' ','')
    ph = r['percposhead']
    nh = r['percneghead']
    neuh = r['percneuhead']
    pc = r['posavgcomms']
    nc = r['negavgcomms']
    neuc = r['neuavgcomms']
    kp = r['avgupscorePOSHL']
    kn = r['avgupscoreNEGHL']
    kn = r['avgupscoreNEUHL']
    wc = r['wordcloud']
    
    for h in holder:
        city = h['city']
        ll = h['ll']
        citylowernospace = city.lower().replace(' ','')
        if ((citylowernospace == rclowernospace) and (rclowernospace not in empty)):
            x = {}
            x['city'] = city
            x['ll'] = ll
            x['posHEADLINEperc'] = ph
            x['negHEADLINEperc'] = nh
            x['neuHEADLINEperc'] = neuh
            x['posavgcomms'] = pc
            x['negavgcomms'] = nc
            x['neuavgcomms'] = neuc
            x['avgKARMApos'] = kp
            x['avgKARMAneg'] = kn
            x['avgKARMAneu'] = kn
            x['wc'] = wc
            
            cities.append(x)
            empty.append(rclowernospace)
            
        elif ((citylowernospace == rclowernospace) and (rclowernospace in empty)):
            pass
        else:
            pass

# %%
for c in cities:
    pprint(c)
# Out:
# {'avgKARMAneg': 14.090909090909092,
#  'avgKARMAneu': 14.090909090909092,
#  'avgKARMApos': 32.27272727272727,
#  'city': 'New York',
#  'll': [40.7127837, -74.0059413],
#  'negHEADLINEperc': 0.10810810810810811,
#  'negavgcomms': 5.75,
#  'neuHEADLINEperc': 0.5945945945945946,
#  'neuavgcomms': 6.2272727272727275,
#  'posHEADLINEperc': 0.2972972972972973,
#  'posavgcomms': 8.272727272727273,
#  'wc': [['new', 7],
#         ['nyc', 6],
#         ['york', 5],
#         ['broadway', 5],
#         ['city', 4],
#         ['nostalgia', 3],
#         ['holiday', 3],
#         ['campaign', 3],
#         ['old', 3],
#         ['help', 3],
#         ['2018', 3],
#         ['running', 2],
#         ['train', 2],
#         ['today', 2],
#         ['state', 2],
#         ['every', 2],
#         ['bridge', 2],
#         ['year', 2],
#         ['classic', 2],
#         ['box', 2],
#         ['penn', 2],
#         ['piece', 2],
#         ['park', 2],
#         ['people', 2],
#         ['amazon', 2],
#         ['art', 2],
#         ['mental', 2],
#         ['health', 2],
#         ['3', 2],
#         ['review', 2]]}
# {'avgKARMAneg': 48.38461538461539,
#  'avgKARMAneu': 48.38461538461539,
#  'avgKARMApos': 5.285714285714286,
#  'city': 'Seattle',
#  'll': [47.6062095, -122.3320708],
#  'negHEADLINEperc': 0.09090909090909091,
#  'negavgcomms': 6.0,
#  'neuHEADLINEperc': 0.5909090909090909,
#  'neuavgcomms': 6.6923076923076925,
#  'posHEADLINEperc': 0.3181818181818182,
#  'posavgcomms': 5.428571428571429,
#  'wc': [['morning', 4],
#         ['seattle', 3],
#         ['view', 2],
#         ['work', 2],
#         ['needle', 2],
#         ['best', 2],
#         ['place', 2],
#         ['christmas', 2],
#         ['hill', 2],
#         ['sunrise', 2],
#         ['downtown', 1],
#         ['hopscotch', 1],
#         ['went', 1],
#         ['begin', 1],
#         ['testing', 1],
#         ['battery', 1],
#         ['powered', 1],
#         ['buses', 1],
#         ['travel', 1],
#         ['140', 1],
#         ['miles', 1],
#         ['charge', 1],
#         ['alki', 1],
#         ['space', 1],
#         ['poking', 1],
#         ['fog', 1],
#         ['desert', 1],
#         ['like', 1],
#         ['landscape', 1],
#         ['rattlesnake', 1]]}
# {'avgKARMAneg': 219.5625,
#  'avgKARMAneu': 219.5625,
#  'avgKARMApos': 65.33333333333333,
#  'city': 'Chicago',
#  'll': [41.8781136, -87.6297982],
#  'negHEADLINEperc': 0.18518518518518517,
#  'negavgcomms': 26.6,
#  'neuHEADLINEperc': 0.5925925925925926,
#  'neuavgcomms': 26.4375,
#  'posHEADLINEperc': 0.2222222222222222,
#  'posavgcomms': 25.833333333333332,
#  'wc': [['chicago', 5],
#         ['snow', 5],
#         ['storm', 4],
#         ['city', 3],
#         ['tracks', 2],
#         ['windy', 2],
#         ['onto', 2],
#         ['effect', 2],
#         ['know', 2],
#         ['home', 2],
#         ['go', 2],
#         ['power', 2],
#         ['street', 2],
#         ['neighbors', 2],
#         ['weekly', 2],
#         ['november', 2],
#         ['26', 2],
#         ['2018', 2],
#         ['like', 1],
#         ['aerial', 1],
#         ['view', 1],
#         ['loop', 1],
#         ['c', 1],
#         ['1938', 1],
#         ['taz', 1],
#         ['float', 1],
#         ['got', 1],
#         ['caught', 1],
#         ['l', 1],
#         ['thanksgiving', 1]]}
# {'avgKARMAneg': 25.214285714285715,
#  'avgKARMAneu': 25.214285714285715,
#  'avgKARMApos': 1.6666666666666667,
#  'city': 'Los Angeles',
#  'll': [34.0522342, -118.2436849],
#  'negHEADLINEperc': 0.26,
#  'negavgcomms': 20.615384615384617,
#  'neuHEADLINEperc': 0.56,
#  'neuavgcomms': 11.25,
#  'posHEADLINEperc': 0.18,
#  'posavgcomms': 5.333333333333333,
#  'wc': [['la', 9],
#         ['hollywood', 5],
#         ['santa', 4],
#         ['monica', 4],
#         ['los', 4],
#         ['angeles', 4],
#         ['california', 3],
#         ['11', 3],
#         ['pier', 2],
#         ['hidden', 2],
#         ['area', 2],
#         ['1', 2],
#         ['game', 2],
#         ['possible', 2],
#         ['car', 2],
#         ['fairfax', 2],
#         ['l', 2],
#         ['parade', 2],
#         ['san', 2],
#         ['red', 2],
#         ['good', 2],
#         ['dance', 2],
#         ['question', 2],
#         ['christmas', 2],
#         ['fire', 2],
#         ['west', 2],
#         ['26', 2],
#         ['two', 1],
#         ['pines', 1],
#         ['chapel', 1]]}
# {'avgKARMAneg': 10.962962962962964,
#  'avgKARMAneu': 10.962962962962964,
#  'avgKARMApos': 45.875,
#  'city': 'Portland',
#  'll': [45.5230622, -122.6764816],
#  'negHEADLINEperc': 0.2553191489361702,
#  'negavgcomms': 47.583333333333336,
#  'neuHEADLINEperc': 0.574468085106383,
#  'neuavgcomms': 5.592592592592593,
#  'posHEADLINEperc': 0.1702127659574468,
#  'posavgcomms': 15.25,
#  'wc': [['portland', 8],
#         ['randomly', 3],
#         ['7', 3],
#         ['year', 3],
#         ['morning', 3],
#         ['2018', 3],
#         ['attacked', 2],
#         ['se', 2],
#         ['hood', 2],
#         ['play', 2],
#         ['coyote', 2],
#         ['bridge', 2],
#         ['park', 2],
#         ['oregon', 2],
#         ['state', 2],
#         ['tree', 2],
#         ['anyone', 2],
#         ['know', 2],
#         ['nice', 2],
#         ['one', 2],
#         ['18', 2],
#         ['students', 2],
#         ['season', 2],
#         ['sharing', 2],
#         ['pdx', 2],
#         ['troutdale', 2],
#         ['20th', 1],
#         ['two', 1],
#         ['hours', 1],
#         ['ago', 1]]}
# {'avgKARMAneg': 35.733333333333334,
#  'avgKARMAneu': 35.733333333333334,
#  'avgKARMApos': 5.333333333333333,
#  'city': 'Boston',
#  'll': [42.3600825, -71.0588801],
#  'negHEADLINEperc': 0.14285714285714285,
#  'negavgcomms': 30.0,
#  'neuHEADLINEperc': 0.7142857142857143,
#  'neuavgcomms': 20.533333333333335,
#  'posHEADLINEperc': 0.14285714285714285,
#  'posavgcomms': 15.333333333333334,
#  'wc': [['boston', 7],
#         ['dorchester', 2],
#         ['heights', 2],
#         ['lieutenant', 2],
#         ['christmas', 2],
#         ['fort', 2],
#         ['traffic', 2],
#         ['street', 2],
#         ['justice', 2],
#         ['drew', 1],
#         ['map', 1],
#         ['1967', 1],
#         ['mbta', 1],
#         ['founded', 1],
#         ['support', 1],
#         ['groups', 1],
#         ['depression', 1],
#         ['fall', 1],
#         ['afternoon', 1],
#         ['south', 1],
#         ['grave', 1],
#         ['2nd', 1],
#         ['artillery', 1],
#         ['robert', 1],
#         ['f', 1],
#         ['massie', 1],
#         ['killed', 1],
#         ['sword', 1],
#         ['duel', 1],
#         ['gustavus', 1]]}
# {'avgKARMAneg': 46.888888888888886,
#  'avgKARMAneu': 46.888888888888886,
#  'avgKARMApos': 10.166666666666666,
#  'city': 'Detroit',
#  'll': [42.331427, -83.0457538],
#  'negHEADLINEperc': 0.16666666666666666,
#  'negavgcomms': 18.0,
#  'neuHEADLINEperc': 0.5,
#  'neuavgcomms': 10.88888888888889,
#  'posHEADLINEperc': 0.3333333333333333,
#  'posavgcomms': 6.166666666666667,
#  'wc': [['detroit', 6],
#         ['general', 2],
#         ['motors', 2],
#         ['close', 2],
#         ['warren', 2],
#         ['gm', 2],
#         ['building', 2],
#         ['infrastructure', 2],
#         ['going', 2],
#         ['city', 1],
#         ['airport', 1],
#         ['entrance', 1],
#         ['built', 1],
#         ['1929', 1],
#         ['1930', 1],
#         ['major', 1],
#         ['ontario', 1],
#         ['plant', 1],
#         ['cut', 1],
#         ['2', 1],
#         ['500', 1],
#         ['jobs', 1],
#         ['plants', 1],
#         ['nature', 1],
#         ['taking', 1],
#         ['care', 1],
#         ['billboard', 1],
#         ['today', 1],
#         ['guardian', 1],
#         ['annex', 1]]}
# {'avgKARMAneg': 97.8,
#  'avgKARMAneu': 97.8,
#  'avgKARMApos': 39.0,
#  'city': 'San Francisco',
#  'll': [37.7749295, -122.4194155],
#  'negHEADLINEperc': 0.14285714285714285,
#  'negavgcomms': 3.6666666666666665,
#  'neuHEADLINEperc': 0.7142857142857143,
#  'neuavgcomms': 4.266666666666667,
#  'posHEADLINEperc': 0.14285714285714285,
#  'posavgcomms': 4.333333333333333,
#  'wc': [['fog', 3],
#         ['view', 2],
#         ['smoke', 2],
#         ['many', 2],
#         ['city', 2],
#         ['1', 2],
#         ['years', 2],
#         ['charged', 2],
#         ['one', 2],
#         ['26', 2],
#         ['ocean', 2],
#         ['refreshing', 1],
#         ['rain', 1],
#         ['divide', 1],
#         ['came', 1],
#         ['philz', 1],
#         ['long', 1],
#         ['night', 1],
#         ['studying', 1],
#         ['found', 1],
#         ['rose', 1],
#         ['handlebars', 1],
#         ['wonderful', 1],
#         ['people', 1],
#         ['transamerica', 1],
#         ['pyramid', 1],
#         ['bench', 1],
#         ['handles', 1],
#         ['near', 1],
#         ['waterfront', 1]]}
# {'avgKARMAneg': 29.043478260869566,
#  'avgKARMAneu': 29.043478260869566,
#  'avgKARMApos': 63.333333333333336,
#  'city': 'Atlanta',
#  'll': [33.7489954, -84.3879824],
#  'negHEADLINEperc': 0.14705882352941177,
#  'negavgcomms': 11.4,
#  'neuHEADLINEperc': 0.6764705882352942,
#  'neuavgcomms': 14.08695652173913,
#  'posHEADLINEperc': 0.17647058823529413,
#  'posavgcomms': 15.666666666666666,
#  'wc': [['atlanta', 10],
#         ['christmas', 4],
#         ['sunday', 3],
#         ['anyone', 3],
#         ['music', 3],
#         ['united', 3],
#         ['26', 3],
#         ['fog', 2],
#         ['early', 2],
#         ['voting', 2],
#         ['runoff', 2],
#         ['atl', 2],
#         ['title', 2],
#         ['year', 2],
#         ['night', 2],
#         ['r', 2],
#         ['november', 2],
#         ['2018', 2],
#         ['georgia', 2],
#         ['events', 2],
#         ['stuck', 2],
#         ['disappeared', 1],
#         ['see', 1],
#         ['guy', 1],
#         ['marietta', 1],
#         ['blasting', 1],
#         ['mariah', 1],
#         ['carey', 1],
#         ['wiiiiiiin', 1],
#         ['rip', 1]]}
# {'avgKARMAneg': 40.411764705882355,
#  'avgKARMAneu': 40.411764705882355,
#  'avgKARMApos': 17.666666666666668,
#  'city': 'Philadelphia',
#  'll': [39.9525839, -75.1652215],
#  'negHEADLINEperc': 0.23529411764705882,
#  'negavgcomms': 17.875,
#  'neuHEADLINEperc': 0.5,
#  'neuavgcomms': 14.117647058823529,
#  'posHEADLINEperc': 0.2647058823529412,
#  'posavgcomms': 23.88888888888889,
#  'wc': [['city', 3],
#         ['flooded', 2],
#         ['first', 2],
#         ['another', 2],
#         ['around', 2],
#         ['philly', 2],
#         ['things', 2],
#         ['philadelphia', 2],
#         ['looking', 1],
#         ['counseling', 1],
#         ['therapy', 1],
#         ['kensington', 1],
#         ['place', 1],
#         ['dreams', 1],
#         ['go', 1],
#         ['die', 1],
#         ['dirtbikers', 1],
#         ['attempt', 1],
#         ['cross', 1],
#         ['columbus', 1],
#         ['blvd', 1],
#         ['finally', 1],
#         ['got', 1],
#         ['experience', 1],
#         ['hand', 1],
#         ['circle', 1],
#         ['life', 1],
#         ['day', 1],
#         ['kelly', 1],
#         ['drive', 1]]}
# {'avgKARMAneg': 37.3,
#  'avgKARMAneu': 37.3,
#  'avgKARMApos': 13.6,
#  'city': 'Columbus',
#  'll': [39.9611755, -82.99879419999999],
#  'negHEADLINEperc': 0.16666666666666666,
#  'negavgcomms': 43.666666666666664,
#  'neuHEADLINEperc': 0.5555555555555556,
#  'neuavgcomms': 20.3,
#  'posHEADLINEperc': 0.2777777777777778,
#  'posavgcomms': 8.6,
#  'wc': [['precipitation', 2],
#         ['state', 2],
#         ['christmas', 2],
#         ['ohio', 2],
#         ['columbus', 2],
#         ['16', 2],
#         ['bit', 2],
#         ['pins', 2],
#         ['cleveland', 2],
#         ['dispatch', 1],
#         ['xenos', 1],
#         ['critics', 1],
#         ['call', 1],
#         ['church', 1],
#         ['cult', 1],
#         ['dan', 1],
#         ['baker', 1],
#         ['overrated', 1],
#         ['cbj', 1],
#         ['get', 1],
#         ['average', 1],
#         ['remainder', 1],
#         ['year', 1],
#         ['end', 1],
#         ['08', 1],
#         ['2011', 1],
#         ['record', 1],
#         ['54', 1],
#         ['96', 1],
#         ['sonic', 1]]}
# {'avgKARMAneg': 20.625,
#  'avgKARMAneu': 20.625,
#  'avgKARMApos': 342.25,
#  'city': 'Dallas',
#  'll': [32.7766642, -96.79698789999999],
#  'negHEADLINEperc': 0.07692307692307693,
#  'negavgcomms': 6.0,
#  'neuHEADLINEperc': 0.6153846153846154,
#  'neuavgcomms': 9.5,
#  'posHEADLINEperc': 0.3076923076923077,
#  'posavgcomms': 13.5,
#  'wc': [['dallas', 5],
#         ['christmas', 2],
#         ['rock', 2],
#         ['thread', 2],
#         ['beginning', 1],
#         ['look', 1],
#         ['lot', 1],
#         ['like', 1],
#         ['good', 1],
#         ['job', 1],
#         ['wish', 1],
#         ['listed', 1],
#         ['airbnb', 1],
#         ['urban', 1],
#         ['tree', 1],
#         ['house', 1],
#         ['near', 1],
#         ['white', 1],
#         ['lake', 1],
#         ['230', 1],
#         ['night', 1],
#         ['extra', 1],
#         ['vigilant', 1],
#         ['go', 1],
#         ['club', 1],
#         ['symmetry', 1],
#         ['trinity', 1],
#         ['river', 1],
#         ['trail', 1],
#         ['dart', 1]]}
# {'avgKARMAneg': 28.333333333333332,
#  'avgKARMAneu': 28.333333333333332,
#  'avgKARMApos': 16.0,
#  'city': 'Baltimore',
#  'll': [39.2903848, -76.6121893],
#  'negHEADLINEperc': 0.05555555555555555,
#  'negavgcomms': 17.0,
#  'neuHEADLINEperc': 0.6666666666666666,
#  'neuavgcomms': 4.583333333333333,
#  'posHEADLINEperc': 0.2777777777777778,
#  'posavgcomms': 7.2,
#  'wc': [['baltimore', 7],
#         ['18', 4],
#         ['street', 2],
#         ['weekly', 2],
#         ['11', 2],
#         ['26', 2],
#         ['12', 2],
#         ['02', 2],
#         ['flying', 1],
#         ['east', 1],
#         ['right', 1],
#         ['video', 1],
#         ['since', 1],
#         ['retiring', 1],
#         ['football', 1],
#         ['aaron', 1],
#         ['maybin', 1],
#         ['dedicated', 1],
#         ['matthew', 1],
#         ['henson', 1],
#         ['elementary', 1],
#         ['school', 1],
#         ['26th', 1],
#         ['verge', 1],
#         ['collapsing', 1],
#         ['two', 1],
#         ['blocks', 1],
#         ['collapsed', 1],
#         ['2014', 1],
#         ['help', 1]]}
# {'avgKARMAneg': 72.52173913043478,
#  'avgKARMAneu': 72.52173913043478,
#  'avgKARMApos': 25.428571428571427,
#  'city': 'San Diego',
#  'll': [32.715738, -117.1610838],
#  'negHEADLINEperc': 0.03225806451612903,
#  'negavgcomms': 16.0,
#  'neuHEADLINEperc': 0.7419354838709677,
#  'neuavgcomms': 44.47826086956522,
#  'posHEADLINEperc': 0.22580645161290322,
#  'posavgcomms': 5.285714285714286,
#  'wc': [['san', 7],
#         ['diego', 6],
#         ['border', 3],
#         ['bridge', 3],
#         ['scene', 2],
#         ['entry', 2],
#         ['today', 2],
#         ['week', 2],
#         ['love', 2],
#         ['place', 2],
#         ['caravan', 2],
#         ['every', 2],
#         ['day', 2],
#         ['food', 2],
#         ['gorgeous', 2],
#         ['train', 2],
#         ['cheap', 2],
#         ['best', 2],
#         ['current', 1],
#         ['ysidro', 1],
#         ['port', 1],
#         ['breaking911', 1],
#         ['twitter', 1],
#         ['caravana', 1],
#         ['migrante', 1],
#         ['tijuana', 1],
#         ['got', 1],
#         ['back', 1],
#         ['chicago', 1],
#         ['currently', 1]]}
# {'avgKARMAneg': 10.55,
#  'avgKARMAneu': 10.55,
#  'avgKARMApos': 99.83333333333333,
#  'city': 'Houston',
#  'll': [29.7604267, -95.3698028],
#  'negHEADLINEperc': 0.07142857142857142,
#  'negavgcomms': 19.5,
#  'neuHEADLINEperc': 0.7142857142857143,
#  'neuavgcomms': 7.1,
#  'posHEADLINEperc': 0.21428571428571427,
#  'posavgcomms': 23.5,
#  'wc': [['houston', 9],
#         ['area', 5],
#         ['way', 2],
#         ['community', 2],
#         ['texas', 2],
#         ['performance', 2],
#         ['basho', 2],
#         ['review', 2],
#         ['anyone', 2],
#         ['know', 2],
#         ['restaurant', 2],
#         ['morning', 2],
#         ['please', 2],
#         ['610', 2],
#         ['recommendations', 2],
#         ['thanh', 2],
#         ['school', 2],
#         ['snapped', 1],
#         ['pic', 1],
#         ['father', 1],
#         ['teaching', 1],
#         ['daughter', 1],
#         ['ride', 1],
#         ['bike', 1],
#         ['today', 1],
#         ['buffalo', 1],
#         ['bayou', 1],
#         ['park', 1],
#         ['sharing', 1],
#         ['hopes', 1]]}
# {'avgKARMAneg': 7.6,
#  'avgKARMAneu': 7.6,
#  'avgKARMApos': 93.0,
#  'city': 'Phoenix',
#  'll': [33.4483771, -112.0740373],
#  'negHEADLINEperc': 0.1111111111111111,
#  'negavgcomms': 16.0,
#  'neuHEADLINEperc': 0.5555555555555556,
#  'neuavgcomms': 8.8,
#  'posHEADLINEperc': 0.3333333333333333,
#  'posavgcomms': 5.666666666666667,
#  'wc': [['phoenix', 3],
#         ['christmas', 3],
#         ['november', 2],
#         ['26', 2],
#         ['must', 2],
#         ['valley', 2],
#         ['recommendations', 2],
#         ['technically', 1],
#         ['boulders', 1],
#         ['ohv', 1],
#         ['trails', 1],
#         ['west', 1],
#         ['lake', 1],
#         ['pleasant', 1],
#         ['r', 1],
#         ['daily', 1],
#         ['discussion', 1],
#         ['thread', 1],
#         ['2018', 1],
#         ['things', 1],
#         ['week', 1],
#         ['december', 1],
#         ['02', 1],
#         ['volunteer', 1],
#         ['opportunities', 1],
#         ['eve', 1],
#         ['stop', 1],
#         ['eatery', 1],
#         ['road', 1],
#         ['trippers', 1]]}
# {'avgKARMAneg': 8.75,
#  'avgKARMAneu': 8.75,
#  'avgKARMApos': 3.0,
#  'city': 'Orlando',
#  'll': [28.5383355, -81.3792365],
#  'negHEADLINEperc': 0.25,
#  'negavgcomms': 10.666666666666666,
#  'neuHEADLINEperc': 0.6666666666666666,
#  'neuavgcomms': 4.0,
#  'posHEADLINEperc': 0.08333333333333333,
#  'posavgcomms': 1.0,
#  'wc': [['orlando', 3],
#         ['anyone', 2],
#         ['paint', 2],
#         ['christmas', 2],
#         ['idea', 2],
#         ['knowledge', 1],
#         ['experience', 1],
#         ['1980s', 1],
#         ['lgbt', 1],
#         ['community', 1],
#         ['know', 1],
#         ['affordable', 1],
#         ['auto', 1],
#         ['shop', 1],
#         ['brake', 1],
#         ['calipers', 1],
#         ['find', 1],
#         ['help', 1],
#         ['google', 1],
#         ['laws', 1],
#         ['public', 1],
#         ['photography', 1],
#         ['video', 1],
#         ['within', 1],
#         ['city', 1],
#         ['personal', 1],
#         ['use', 1],
#         ['urgent', 1],
#         ['need', 1],
#         ['someone', 1]]}
# {'avgKARMAneg': 18.0,
#  'avgKARMAneu': 18.0,
#  'avgKARMApos': 3.0,
#  'city': 'Miami',
#  'll': [25.7616798, -80.1917902],
#  'negHEADLINEperc': 0.1111111111111111,
#  'negavgcomms': 61.0,
#  'neuHEADLINEperc': 0.6666666666666666,
#  'neuavgcomms': 6.5,
#  'posHEADLINEperc': 0.2222222222222222,
#  'posavgcomms': 0.5,
#  'wc': [['miami', 3],
#         ['key', 2],
#         ['fog', 2],
#         ['route', 1],
#         ['biscayne', 1],
#         ['another', 1],
#         ['cyclist', 1],
#         ['killed', 1],
#         ['streets', 1],
#         ['south', 1],
#         ['florida', 1],
#         ['tonight', 1],
#         ['sunset', 1],
#         ['virginai', 1],
#         ['sail', 1],
#         ['ford', 1],
#         ['argo', 1],
#         ['embrace', 1],
#         ['steep', 1],
#         ['self', 1],
#         ['driving', 1],
#         ['learning', 1],
#         ['curve', 1],
#         ['morning', 1],
#         ['living', 1],
#         ['40k', 1],
#         ['medical', 1],
#         ['rotations', 1],
#         ['hialeah', 1],
#         ['tips', 1]]}

# %%
with open('cityreddit.json', 'w') as outfile:  
    json.dump({'cities': cities} , outfile)

# %%
empty = []
cities = []

cd = {}

for r in reddocs:
    rcity = r['location']
    rclowernospace = rcity.lower().replace(' ','')
    ph = r['percposhead']
    nh = r['percneghead']
    neuh = r['percneuhead']
    pc = r['posavgcomms']
    nc = r['negavgcomms']
    neuc = r['neuavgcomms']
    kp = r['avgupscorePOSHL']
    kn = r['avgupscoreNEGHL']
    kn = r['avgupscoreNEUHL']
    wc = r['wordcloud']
    
    for h in holder:
        city = h['city']
        ll = h['ll']
        citylowernospace = city.lower().replace(' ','')
        if ((citylowernospace == rclowernospace) and (rclowernospace not in empty)):
            x = {}

            x['posHEADLINEperc'] = ph
            x['negHEADLINEperc'] = nh
            x['neuHEADLINEperc'] = neuh
            x['posavgcomms'] = pc
            x['negavgcomms'] = nc
            x['neuavgcomms'] = neuc
            x['avgKARMApos'] = kp
            x['avgKARMAneg'] = kn
            x['avgKARMAneu'] = kn
            x['wc'] = wc
            
            cities.append(x)
            
            cd['city'] = city
            
            
            empty.append(rclowernospace)
            
        elif ((citylowernospace == rclowernospace) and (rclowernospace in empty)):
            pass
        else:
            pass
