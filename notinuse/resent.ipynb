# %%
import numpy as np
import datetime as dt
import pymongo
from pprint import pprint
import pandas as pd

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.project_reax

# %%
#no nevada, it's bad news

states = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware', 'Florida', 'Georgia','Hawaii', 
'Idaho', 'Illinois','Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
'Mississippi', 'Missouri', 'Montana','Nebraska', 'NewHampshire', 'NewJersey', 'NewMexico', 'NewYork', 'NorthCarolina', 
'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'RhodeIsland', 'SouthCarolina', 'SouthDakota','Tennessee', 'Texas', 
'Utah', 'Vermont', 'Virginia', 'Washington', 'WestVirginia', 'Wisconsin', 'Wyoming']

# %%
city_subreddits = ['NYC', 'Seattle', 'Chicago', 'LosAngeles', 'Portland', 'Boston', 'Austin', 
'SanFrancisco', 'Atlanta', 'Philadelphia', 'Denver', "Columbus",
'Dallas', 'Baltimore', 'StLouis', 'BayArea', 'washingtondc', 
'twincitiessocial', 'sandiego', 'pittsburgh', 'houston', "Anchorage", "phoenix", 'Sacramento', "orlando",
 "louisville", "neworleans", "nashville", "Miami", "vegas", "SaltLakeCity"]

# %%
ssho = []
#state level
for state in states:
    s = state.lower()
    docs = db.reddit_state.aggregate(
    [ { "$match" : { 'location' : s } } ]
    )
    vsc = []
    vsp = []
    vsn = []
    kc = []
    ku = []
    
    print(state)
#     print(state)
#     print(len(list(docs)))
    doclength = 0

    if (len(list(docs)) != doclength):
        print("true -----------------------")
        docs = db.reddit_state.aggregate([ { "$match" : { 'location' : s } } ])
#     elif (s == 'nevada'):
#         print("nevada")
#         docs = db.reddit_state.aggregate([ { "$match" : { 'location' : state } } ])
    else:
        print("false______________________________")
        docs = db.reddit_state.aggregate([ { "$match" : { 'location' : state } } ])

#document of state level
    for d in docs:
        #if docs level
        if (len(d['comment_dict']) > 0): 
            length = len(d['comment_dict'])
            
            #for each d in docs
            for x in range(length):
                vsc.append(d['comment_dict'][x]['vader']['compound'])
                vsp.append(d['comment_dict'][x]['vader']['pos'])
                vsn.append(d['comment_dict'][x]['vader']['neg'])
                kc.append(d['comment_dict'][x]['karma']['compound'])
                ku.append(d['comment_dict'][x]['karma']['ups'])

#             print(len(vsc))
#             print(len(vsp))
#             print(len(vsn))
#             print(len(kc))
#             print(len(ku))
        
    
    cs = float(np.mean(vsc))
    pos = float(np.mean(vsp))
    neg = float(np.mean(vsn))
    kcom = float(np.sum(kc))
    kup = float(np.sum(ku))
#     print(cs)
#     print(pos)
#     print(neg)
#     print(kcom)
#     print(kup)
    day = dt.datetime.now().strftime('%Y-%m-%d')
    
    location_sentiments = dict( location = s,
                                datetime = day,
                                vaderCom = cs,
                                vaderPos = pos,
                                vaderNeg = neg,
                                karmaUp = kup,
                                karmaCom = kcom )
#     print(location_sentiments)
    
    ssho.append(location_sentiments)
# Out:
# Alabama
# false______________________________
# Alaska
# true -----------------------
# Arizona
# true -----------------------
# Arkansas
# false______________________________
# California
# false______________________________
# Colorado
# false______________________________
# Connecticut
# false______________________________
# Delaware
# false______________________________
# Florida
# true -----------------------
# Georgia
# false______________________________
# Hawaii
# false______________________________
# Idaho
# false______________________________
# Illinois
# true -----------------------
# Indiana
# false______________________________
# Iowa
# false______________________________
# Kansas
# true -----------------------
# Kentucky
# false______________________________
# Louisiana
# false______________________________
# Maine
# false______________________________
# Maryland
# true -----------------------
# Massachusetts
# true -----------------------
# Michigan
# false______________________________
# Minnesota
# true -----------------------
# Mississippi
# true -----------------------
# Missouri
# true -----------------------
# Montana
# false______________________________
# Nebraska
# false______________________________
# NewHampshire
# true -----------------------
# NewJersey
# true -----------------------
# NewMexico
# false______________________________
# NewYork
# true -----------------------
# NorthCarolina
# false______________________________
# NorthDakota
# true -----------------------
# Ohio
# false______________________________
# Oklahoma
# true -----------------------
# Oregon
# true -----------------------
# Pennsylvania
# false______________________________
# RhodeIsland
# false______________________________
# SouthCarolina
# true -----------------------
# SouthDakota
# false______________________________
# Tennessee
# false______________________________
# Texas
# true -----------------------
# Utah
# false______________________________
# Vermont
# true -----------------------
# Virginia
# false______________________________
# Washington
# false______________________________
# WestVirginia
# false______________________________
# Wisconsin
# true -----------------------
# Wyoming
# true -----------------------
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
pprint([s['location'] for s in ssho])
# Out:
# ['alabama',
#  'alaska',
#  'arizona',
#  'arkansas',
#  'california',
#  'colorado',
#  'connecticut',
#  'delaware',
#  'florida',
#  'georgia',
#  'hawaii',
#  'idaho',
#  'illinois',
#  'indiana',
#  'iowa',
#  'kansas',
#  'kentucky',
#  'louisiana',
#  'maine',
#  'maryland',
#  'massachusetts',
#  'michigan',
#  'minnesota',
#  'mississippi',
#  'missouri',
#  'montana',
#  'nebraska',
#  'newhampshire',
#  'newjersey',
#  'newmexico',
#  'newyork',
#  'northcarolina',
#  'northdakota',
#  'ohio',
#  'oklahoma',
#  'oregon',
#  'pennsylvania',
#  'rhodeisland',
#  'southcarolina',
#  'southdakota',
#  'tennessee',
#  'texas',
#  'utah',
#  'vermont',
#  'virginia',
#  'washington',
#  'westvirginia',
#  'wisconsin',
#  'wyoming']

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.project_reax

db.statered_sent.insert_many(ssho)

# %%
csho = []
#state level
for city in city_subreddits:
    c = city.lower()
    docs = db.reddit_city.aggregate(
    [ { "$match" : { 'location' : city, 'datetime': dt.datetime.now().strftime('%Y-%m-%d') } } ]
    )
    vsc = []
    vsp = []
    vsn = []
    kc = []
    ku = [] 
    print(city)
    

    doclength = 0

    if (len(list(docs)) != doclength):
        print("true -----------------------")
        docs = db.reddit_city.aggregate([ { "$match" : { 'location' : city, 'datetime': dt.datetime.now().strftime('%Y-%m-%d') } } ])

    else:
        print("false______________________________")
        docs = db.reddit_city.aggregate([ { "$match" : { 'location' : c, 'datetime': dt.datetime.now().strftime('%Y-%m-%d') } } ])
        
#document of state level
    for d in docs:
        #if docs level
        if (len(d['comment_dict']) > 0): 
            length = len(d['comment_dict'])
            
            #for each d in docs
            for x in range(length):
                vsc.append(d['comment_dict'][x]['vader']['compound'])
                vsp.append(d['comment_dict'][x]['vader']['pos'])
                vsn.append(d['comment_dict'][x]['vader']['neg'])
                kc.append(d['comment_dict'][x]['karma']['compound'])
                ku.append(d['comment_dict'][x]['karma']['ups'])
#             print(len(vsc))
#             print(len(vsp))
#             print(len(vsn))
#             print(len(kc))
#             print(len(ku))
        
    
    cs = float(np.mean(vsc))
    pos = float(np.mean(vsp))
    neg = float(np.mean(vsn))
    kcom = float(np.sum(kc))
    kup = float(np.sum(ku))
#     print(cs)
#     print(pos)
#     print(neg)
#     print(kcom)
    print(kup)
    
    if (c == 'nyc'):
        c = "newyorkcity"
    elif (c == 'twincitiessocial'):
        c = 'minneapolis'
    elif (c == 'bayarea'):
        c = 'oakland'
    else:
        c = c
        
    day = dt.datetime.now().strftime('%Y-%m-%d')
    
    location_sentiments = dict( location = c,
                                datetime = day,
                                vaderCom = cs,
                                vaderPos = pos,
                                vaderNeg = neg,
                                karmaUp = kup,
                                karmaCom = kcom )
#     print(location_sentiments)
    
    csho.append(location_sentiments)
# Out:
# NYC
# false______________________________
# 614.0
# Seattle
# true -----------------------
# 235.0
# Chicago
# false______________________________
# 390.0
# LosAngeles
# true -----------------------
# 2150.0
# Portland
# true -----------------------
# 1341.0
# Boston
# false______________________________
# 814.0
# Austin
# true -----------------------
# 842.0
# SanFrancisco
# false______________________________
# 554.0
# Atlanta
# true -----------------------
# 951.0
# Philadelphia
# false______________________________
# 1684.0
# Denver
# true -----------------------
# 960.0
# Columbus
# true -----------------------
# 478.0
# Dallas
# true -----------------------
# 69.0
# Baltimore
# false______________________________
# 311.0
# StLouis
# true -----------------------
# 75.0
# BayArea
# false______________________________
# 583.0
# washingtondc
# true -----------------------
# 594.0
# twincitiessocial
# true -----------------------
# 6.0
# sandiego
# true -----------------------
# 393.0
# pittsburgh
# true -----------------------
# 709.0
# houston
# true -----------------------
# 894.0
# Anchorage
# false______________________________
# 6.0
# phoenix
# true -----------------------
# 754.0
# Sacramento
# true -----------------------
# 190.0
# orlando
# true -----------------------
# 316.0
# louisville
# false______________________________
# 0.0
# neworleans
# false______________________________
# 0.0
# nashville
# true -----------------------
# 482.0
# Miami
# true -----------------------
# 25.0
# vegas
# true -----------------------
# 343.0
# SaltLakeCity
# true -----------------------
# 1639.0
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\site-packages\numpy\core\fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\APG\Anaconda3\envs\AngelosAwesomeEnvironment\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
pprint(csho)
# Out:
# [{'datetime': '2018-11-24',
#   'karmaCom': 614.0,
#   'karmaUp': 614.0,
#   'location': 'newyorkcity',
#   'vaderCom': 0.12964499999999998,
#   'vaderNeg': 0.06985,
#   'vaderPos': 0.12580000000000002},
#  {'datetime': '2018-11-24',
#   'karmaCom': 235.0,
#   'karmaUp': 235.0,
#   'location': 'seattle',
#   'vaderCom': 0.2168076923076923,
#   'vaderNeg': 0.05513461538461538,
#   'vaderPos': 0.14967307692307694},
#  {'datetime': '2018-11-24',
#   'karmaCom': 390.0,
#   'karmaUp': 390.0,
#   'location': 'chicago',
#   'vaderCom': 0.09333552631578945,
#   'vaderNeg': 0.07100000000000001,
#   'vaderPos': 0.0883421052631579},
#  {'datetime': '2018-11-24',
#   'karmaCom': 2150.0,
#   'karmaUp': 2150.0,
#   'location': 'losangeles',
#   'vaderCom': 0.12773494623655915,
#   'vaderNeg': 0.07756989247311828,
#   'vaderPos': 0.16440860215053765},
#  {'datetime': '2018-11-24',
#   'karmaCom': 1341.0,
#   'karmaUp': 1341.0,
#   'location': 'portland',
#   'vaderCom': 0.16566033519553072,
#   'vaderNeg': 0.0494804469273743,
#   'vaderPos': 0.12195530726256984},
#  {'datetime': '2018-11-24',
#   'karmaCom': 814.0,
#   'karmaUp': 814.0,
#   'location': 'boston',
#   'vaderCom': 0.0974788888888889,
#   'vaderNeg': 0.1031111111111111,
#   'vaderPos': 0.1413333333333333},
#  {'datetime': '2018-11-24',
#   'karmaCom': 842.0,
#   'karmaUp': 842.0,
#   'location': 'austin',
#   'vaderCom': 0.171564039408867,
#   'vaderNeg': 0.07166502463054188,
#   'vaderPos': 0.17197044334975367},
#  {'datetime': '2018-11-24',
#   'karmaCom': 554.0,
#   'karmaUp': 554.0,
#   'location': 'sanfrancisco',
#   'vaderCom': 0.27891111111111105,
#   'vaderNeg': 0.04352380952380953,
#   'vaderPos': 0.22576190476190475},
#  {'datetime': '2018-11-24',
#   'karmaCom': 951.0,
#   'karmaUp': 951.0,
#   'location': 'atlanta',
#   'vaderCom': 0.17234864864864866,
#   'vaderNeg': 0.0520990990990991,
#   'vaderPos': 0.12717117117117116},
#  {'datetime': '2018-11-24',
#   'karmaCom': 1684.0,
#   'karmaUp': 1684.0,
#   'location': 'philadelphia',
#   'vaderCom': 0.14159999999999998,
#   'vaderNeg': 0.07384699453551913,
#   'vaderPos': 0.140224043715847},
#  {'datetime': '2018-11-24',
#   'karmaCom': 960.0,
#   'karmaUp': 960.0,
#   'location': 'denver',
#   'vaderCom': 0.10962242990654207,
#   'vaderNeg': 0.07809345794392523,
#   'vaderPos': 0.1349532710280374},
#  {'datetime': '2018-11-24',
#   'karmaCom': 478.0,
#   'karmaUp': 478.0,
#   'location': 'columbus',
#   'vaderCom': 0.13068387096774192,
#   'vaderNeg': 0.06982258064516128,
#   'vaderPos': 0.12429032258064517},
#  {'datetime': '2018-11-24',
#   'karmaCom': 69.0,
#   'karmaUp': 69.0,
#   'location': 'dallas',
#   'vaderCom': 0.25377000000000005,
#   'vaderNeg': 0.051949999999999996,
#   'vaderPos': 0.24625},
#  {'datetime': '2018-11-24',
#   'karmaCom': 311.0,
#   'karmaUp': 311.0,
#   'location': 'baltimore',
#   'vaderCom': 0.12911803278688525,
#   'vaderNeg': 0.0688032786885246,
#   'vaderPos': 0.14265573770491807},
#  {'datetime': '2018-11-24',
#   'karmaCom': 75.0,
#   'karmaUp': 75.0,
#   'location': 'stlouis',
#   'vaderCom': 0.1418626666666667,
#   'vaderNeg': 0.04228,
#   'vaderPos': 0.09872},
#  {'datetime': '2018-11-24',
#   'karmaCom': 583.0,
#   'karmaUp': 583.0,
#   'location': 'oakland',
#   'vaderCom': 0.14904642857142858,
#   'vaderNeg': 0.06432142857142857,
#   'vaderPos': 0.10953571428571429},
#  {'datetime': '2018-11-24',
#   'karmaCom': 594.0,
#   'karmaUp': 594.0,
#   'location': 'washingtondc',
#   'vaderCom': 0.17314137931034482,
#   'vaderNeg': 0.09129310344827586,
#   'vaderPos': 0.15786206896551722},
#  {'datetime': '2018-11-24',
#   'karmaCom': 6.0,
#   'karmaUp': 6.0,
#   'location': 'minneapolis',
#   'vaderCom': 0.4061666666666666,
#   'vaderNeg': 0.004333333333333333,
#   'vaderPos': 0.119},
#  {'datetime': '2018-11-24',
#   'karmaCom': 393.0,
#   'karmaUp': 393.0,
#   'location': 'sandiego',
#   'vaderCom': 0.16993750000000002,
#   'vaderNeg': 0.052556818181818184,
#   'vaderPos': 0.1268977272727273},
#  {'datetime': '2018-11-24',
#   'karmaCom': 709.0,
#   'karmaUp': 709.0,
#   'location': 'pittsburgh',
#   'vaderCom': 0.255,
#   'vaderNeg': 0.06664102564102564,
#   'vaderPos': 0.1436538461538462},
#  {'datetime': '2018-11-24',
#   'karmaCom': 894.0,
#   'karmaUp': 894.0,
#   'location': 'houston',
#   'vaderCom': 0.13779285714285713,
#   'vaderNeg': 0.052316326530612245,
#   'vaderPos': 0.09219387755102039},
#  {'datetime': '2018-11-24',
#   'karmaCom': 6.0,
#   'karmaUp': 6.0,
#   'location': 'anchorage',
#   'vaderCom': 0.5687,
#   'vaderNeg': 0.009,
#   'vaderPos': 0.1235},
#  {'datetime': '2018-11-24',
#   'karmaCom': 754.0,
#   'karmaUp': 754.0,
#   'location': 'phoenix',
#   'vaderCom': 0.15855571428571433,
#   'vaderNeg': 0.07431428571428571,
#   'vaderPos': 0.15310000000000004},
#  {'datetime': '2018-11-24',
#   'karmaCom': 190.0,
#   'karmaUp': 190.0,
#   'location': 'sacramento',
#   'vaderCom': 0.11533478260869565,
#   'vaderNeg': 0.06991304347826087,
#   'vaderPos': 0.10041304347826087},
#  {'datetime': '2018-11-24',
#   'karmaCom': 316.0,
#   'karmaUp': 316.0,
#   'location': 'orlando',
#   'vaderCom': 0.22447272727272727,
#   'vaderNeg': 0.039181818181818186,
#   'vaderPos': 0.14516363636363638},
#  {'datetime': '2018-11-24',
#   'karmaCom': 0.0,
#   'karmaUp': 0.0,
#   'location': 'louisville',
#   'vaderCom': nan,
#   'vaderNeg': nan,
#   'vaderPos': nan},
#  {'datetime': '2018-11-24',
#   'karmaCom': 0.0,
#   'karmaUp': 0.0,
#   'location': 'neworleans',
#   'vaderCom': nan,
#   'vaderNeg': nan,
#   'vaderPos': nan},
#  {'datetime': '2018-11-24',
#   'karmaCom': 482.0,
#   'karmaUp': 482.0,
#   'location': 'nashville',
#   'vaderCom': 0.2582102272727273,
#   'vaderNeg': 0.053625000000000006,
#   'vaderPos': 0.1615909090909091},
#  {'datetime': '2018-11-24',
#   'karmaCom': 25.0,
#   'karmaUp': 25.0,
#   'location': 'miami',
#   'vaderCom': 0.08676399999999998,
#   'vaderNeg': 0.057319999999999996,
#   'vaderPos': 0.14},
#  {'datetime': '2018-11-24',
#   'karmaCom': 343.0,
#   'karmaUp': 343.0,
#   'location': 'vegas',
#   'vaderCom': 0.09622068965517243,
#   'vaderNeg': 0.09163793103448276,
#   'vaderPos': 0.1015},
#  {'datetime': '2018-11-24',
#   'karmaCom': 1639.0,
#   'karmaUp': 1639.0,
#   'location': 'saltlakecity',
#   'vaderCom': 0.23835089820359281,
#   'vaderNeg': 0.08004191616766468,
#   'vaderPos': 0.14289221556886228}]

# %%
db.cityred_sent.insert_many(csho)
