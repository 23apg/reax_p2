# %%
import json
from pprint import pprint
import numpy as np
import datetime as dt
import pymongo

# %%
states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas','California','Colorado', 'Connecticut','Delaware', 'washingtondc', 'Florida', 
'Georgia','Hawaii', 'Idaho', 'Illinois','Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 
'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana','Nebraska', 'Nevada', 'NewHampshire', 
'NewJersey', 'NewMexico', 'NewYork', 'NorthCarolina', 'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 
'RhodeIsland', 'SouthCarolina', 'SouthDakota','Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 
'WestVirginia', 'Wisconsin', 'Wyoming']

# %%
def STATEget_data_onjson(lllllisty):        
    
    hd = []
    for state in states:
        s = state
        doc = db.state_simple.aggregate( 
        [ { "$match" : { 'location' : s } } ]
        )
        for d in doc:
            posHEADLINEperc = d['percposhead']
            negHEADLINEperc = d['percneghead']
            neuHEADLINEperc = d['percneuhead']
            avgKARMApos = d['avgupscorePOSHL']
            avgKARMAneg = d['avgupscoreNEGHL']
            avgKARMAneu = d['avgupscoreNEUHL']
            posavgcomms = d['posavgcomms']
            negavgcomms = d['negavgcomms']
            neuavgcomms = d['neuavgcomms']        
            keys = d['keys']

        ss = {"location" : s,
              "posHEADLINEperc" : posHEADLINEperc,
              "negHEADLINEperc" : negHEADLINEperc,
              "neuHEADLINEperc" : neuHEADLINEperc,
              'posavgcomms' : posavgcomms,
              "negavgcomms" : negavgcomms,
              "neuavgcomms" : neuavgcomms,
              "avgKARMApos" : avgKARMApos,
              "avgKARMAneg" : avgKARMAneg,
              'avgKARMAneu' : avgKARMAneu,
              'keys': keys}
        hd.append(ss)
        
    return(hd)

def CITYget_data_onjson(lllllisty):        
    
    hd = []
    for state in states:
        s = state
        doc = db.city_simple.aggregate( 
        [ { "$match" : { 'location' : s } } ]
        )
        for d in doc:
            posHEADLINEperc = d['percposhead']
            negHEADLINEperc = d['percneghead']
            neuHEADLINEperc = d['percneuhead']
            avgKARMApos = d['avgupscorePOSHL']
            avgKARMAneg = d['avgupscoreNEGHL']
            avgKARMAneu = d['avgupscoreNEUHL']
            posavgcomms = d['posavgcomms']
            negavgcomms = d['negavgcomms']
            neuavgcomms = d['neuavgcomms']        
            keys = d['keys']

        ss = {"location" : s,
              "posHEADLINEperc" : posHEADLINEperc,
              "negHEADLINEperc" : negHEADLINEperc,
              "neuHEADLINEperc" : neuHEADLINEperc,
              'posavgcomms' : posavgcomms,
              "negavgcomms" : negavgcomms,
              "neuavgcomms" : neuavgcomms,
              "avgKARMApos" : avgKARMApos,
              "avgKARMAneg" : avgKARMAneg,
              'avgKARMAneu' : avgKARMAneu,
              'keys': keys}
        hd.append(ss)
        
    return(hd)

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.project_reax

# %%
hd = STATEget_data_onjson(states)

# %%
pprint(hd[1])
# Out:
# {'avgKARMAneg': 73.33333333333333,
#  'avgKARMAneu': 100.73333333333333,
#  'avgKARMApos': 96.92857142857143,
#  'keys': [' ',
#           'Pumpkin',
#           'winter',
#           'Costco',
#           'today',
#           'Fairbanks Get',
#           'Alaskans',
#           'Golden Heart',
#           'Alaska',
#           'Matanuska',
#           'Glacier 2 years ago',
#           'Alaskan',
#           'summer',
#           'Moose TV',
#           'Bird',
#           'Bear Mountain Alaska',
#           'every day',
#           'Instagram @creative_hustler_company',
#           'Eagle River Nature Center',
#           'yesterday',
#           'afternoon',
#           'Eklutna Lake',
#           'Palmer',
#           'Alaska Landing',
#           'Anchorage',
#           'Mount Wrather',
#           'Juneau Alaska',
#           'a few years',
#           'First',
#           'November',
#           'Matrix',
#           'Kincaid Park',
#           'Carol Inlet',
#           'Winter',
#           '907',
#           'FlatTop Alaska',
#           'Nome Winter',
#           'Thanksgiving',
#           'tomorrow',
#           '40',
#           'Tomorrow',
#           'TIL',
#           'the United States',
#           '2nd',
#           '7th',
#           'Ionia',
#           'Pioneer Peak',
#           'Flattop',
#           'Mary Pete',
#           'Alaska Palmer',
#           'Aurora',
#           'Eagle River',
#           'tonight',
#           '2 a.m.',
#           'Doing Jack Skellington',
#           'Halloween',
#           'the end of the month',
#           'Enforcement Training Center',
#           '2018',
#           '41.44 Percent',
#           'Denali',
#           'the Overlook at Flattop',
#           'last month',
#           'Dunleavy',
#           'GOP',
#           'Don Young',
#           'Walker',
#           'Raven',
#           'North-East of Anchorage',
#           'Canadians',
#           'The Sterling Highway Out',
#           'Juneau',
#           'May a few years',
#           'the fall months',
#           'Fairbanks Volunteers',
#           'hundreds',
#           'Anchorage seniors Public Service Announcement',
#           'Mountain View',
#           'quarter',
#           'Pete Kelly',
#           'Sitka',
#           'Gov',
#           'Permanent Fund',
#           'Trails Alyse Galvin',
#           '1',
#           '6 million acres',
#           'Meet',
#           'two',
#           '700,000',
#           'Mike Dunleavy Alaska',
#           'Whale',
#           'Herd',
#           "Glennallen Dunleavy's",
#           'New Alaska',
#           'The Election Deadline',
#           'Another beautiful morning',
#           'Lake Hood',
#           'Bass Pro Shops',
#           '25k',
#           'Stand',
#           'Salmon Dunleavy',
#           'second',
#           '200',
#           'Hawaii',
#           'Hundreds',
#           'Northern Lights',
#           'last night',
#           'SC Alaska',
#           '8:00 pm',
#           'Begich',
#           '42.2%',
#           '42.5%'],
#  'location': 'Alaska',
#  'negHEADLINEperc': 0.12,
#  'negavgcomms': 22.833333333333332,
#  'neuHEADLINEperc': 0.6,
#  'neuavgcomms': 15.383333333333333,
#  'posHEADLINEperc': 0.28,
#  'posavgcomms': 16.107142857142858}

# %%
with open('statesData.json') as f:
    data = json.load(f)

# %%
empty = []

for d in data['features']:
    statenamejson = d['properties']['name']
    statelower = statenamejson.lower()
    state = statelower.replace(' ', '')
    for h in hd:        
        hstate = h['location']
        if (hstate == 'washingtondc'):
            hstate = 'districtofcolumbia'
        else:
            hstate = hstate
        hsl = hstate.lower()
        hs = hsl.replace(' ', '')
        if (hs == state) and (hs not in empty):
#             print(hs + " " + state)
            empty.append(hs)
            d['properties']['posHEADLINEperc'] = h['posHEADLINEperc']
            d['properties']['negHEADLINEperc'] = h['negHEADLINEperc']
            d['properties']['neuHEADLINEperc'] = h['neuHEADLINEperc']
            d['properties']['posavgcomms'] = h['posavgcomms']
            d['properties']['negavgcomms'] = h['negavgcomms']
            d['properties']['neuavgcomms'] = h['neuavgcomms']
            d['properties']['avgKARMApos'] = h['avgKARMApos']
            d['properties']['avgKARMAneg'] = h['avgKARMAneg']
            d['properties']['avgKARMAneu'] = h['avgKARMAneu']
            d['properties']['keys'] = h['keys']
            
#             pprint(d['properties']['name'])
#             pprint(d['properties'])

with open('NEWstate.json', 'w') as f:
    json.dump(data,f)
# Out:
# 'Alabama'
# {'avgKARMAneg': 46.44444444444444,
#  'avgKARMAneu': 47.0188679245283,
#  'avgKARMApos': 25.0,
#  'density': 94.65,
#  'keys': ['Alabama',
#           'Mississippi',
#           '10 years ago',
#           'Stephen Fry',
#           'the Iron Bowl',
#           'US',
#           'Americans',
#           'British',
#           '30 years',
#           'Hinton',
#           'Today',
#           '7am',
#           'Auburn',
#           '1',
#           '2',
#           'Thanksgiving',
#           'Bentley',
#           'Vegas',
#           'Maddox',
#           'Chronic',
#           'Doug Jones',
#           'Rolltide',
#           'Fines',
#           'Fees System Preys On The Poor Archdiocese',
#           'Mobile',
#           '1950',
#           'Dick Brewbaker’s',
#           '10',
#           'the State House',
#           'Shunnarah',
#           'TIL',
#           'McDonald',
#           'EPA',
#           'Sentinelese',
#           'Galleria',
#           'thousands',
#           'Riverchase Galleria',
#           'SBI',
#           'Norml Alabama',
#           'Marijuana',
#           'Legal',
#           'Legal Gambling',
#           'Christian',
#           'Ten',
#           'Matt Hart',
#           'Steve Marshall',
#           'Jones Sees',
#           'Alabama Jobs',
#           'GA',
#           'yesterday',
#           'Us',
#           'Them',
#           'An Automotive Force',
#           'Mueller',
#           'Midterms 2018 Voting',
#           'Tuesday, November 6th',
#           '7am to 7pm',
#           'Talladega Walmart',
#           'Catholic',
#           'Half',
#           'Tuscumbia Waffle House',
#           'Hoover',
#           'Montgomery',
#           'Jerry Brown',
#           'Alabama DA',
#           'Veterans Day',
#           'Jake Tapper',
#           'Sessions',
#           '2020',
#           'Democrat',
#           'Alabama Senate',
#           'Will Ainsworth',
#           'State',
#           'Automatic Voter Registration of US Citizens at the DMV',
#           'Cannabidiol',
#           'Shelby County',
#           'Clark Morris',
#           'AG',
#           'the Court Square Fountain',
#           'AL',
#           'Toronto',
#           'Tuscaloosa',
#           "D-Day '",
#           'PACT',
#           "Kay Ivey's",
#           "Neck Guy'",
#           'Lee County',
#           'Alabama Congressional',
#           'I-20 for 3 hours',
#           '2018',
#           'Madison',
#           'Jeff Sessions',
#           'Trump’s',
#           'this morning',
#           'Huntsville',
#           'Nov. 7th',
#           'WWII',
#           'Amendment 1 & 2',
#           "Trump's Twitter Trade War Autopsy",
#           'Democrats',
#           'two',
#           'Ostrich',
#           'Ask Supreme Court to Review Abortion',
#           'the Democratic Party Ran Competitive',
#           'Serious Candidates Potential',
#           'Auburn University'],
#  'name': 'Alabama',
#  'negHEADLINEperc': 0.36,
#  'negavgcomms': 25.61111111111111,
#  'neuHEADLINEperc': 0.53,
#  'neuavgcomms': 22.452830188679247,
#  'posHEADLINEperc': 0.11,
#  'posavgcomms': 13.818181818181818}
# 'Alaska'
# {'avgKARMAneg': 73.33333333333333,
#  'avgKARMAneu': 100.73333333333333,
#  'avgKARMApos': 96.92857142857143,
#  'density': 1.264,
#  'keys': [' ',
#           'Pumpkin',
#           'winter',
#           'Costco',
#           'today',
#           'Fairbanks Get',
#           'Alaskans',
#           'Golden Heart',
#           'Alaska',
#           'Matanuska',
#           'Glacier 2 years ago',
#           'Alaskan',
#           'summer',
#           'Moose TV',
#           'Bird',
#           'Bear Mountain Alaska',
#           'every day',
#           'Instagram @creative_hustler_company',
#           'Eagle River Nature Center',
#           'yesterday',
#           'afternoon',
#           'Eklutna Lake',
#           'Palmer',
#           'Alaska Landing',
#           'Anchorage',
#           'Mount Wrather',
#           'Juneau Alaska',
#           'a few years',
#           'First',
#           'November',
#           'Matrix',
#           'Kincaid Park',
#           'Carol Inlet',
#           'Winter',
#           '907',
#           'FlatTop Alaska',
#           'Nome Winter',
#           'Thanksgiving',
#           'tomorrow',
#           '40',
#           'Tomorrow',
#           'TIL',
#           'the United States',
#           '2nd',
#           '7th',
#           'Ionia',
#           'Pioneer Peak',
#           'Flattop',
#           'Mary Pete',
#           'Alaska Palmer',
#           'Aurora',
#           'Eagle River',
#           'tonight',
#           '2 a.m.',
#           'Doing Jack Skellington',
#           'Halloween',
#           'the end of the month',
#           'Enforcement Training Center',
#           '2018',
#           '41.44 Percent',
#           'Denali',
#           'the Overlook at Flattop',
#           'last month',
#           'Dunleavy',
#           'GOP',
#           'Don Young',
#           'Walker',
#           'Raven',
#           'North-East of Anchorage',
#           'Canadians',
#           'The Sterling Highway Out',
#           'Juneau',
#           'May a few years',
#           'the fall months',
#           'Fairbanks Volunteers',
#           'hundreds',
#           'Anchorage seniors Public Service Announcement',
#           'Mountain View',
#           'quarter',
#           'Pete Kelly',
#           'Sitka',
#           'Gov',
#           'Permanent Fund',
#           'Trails Alyse Galvin',
#           '1',
#           '6 million acres',
#           'Meet',
#           'two',
#           '700,000',
#           'Mike Dunleavy Alaska',
#           'Whale',
#           'Herd',
#           "Glennallen Dunleavy's",
#           'New Alaska',
#           'The Election Deadline',
#           'Another beautiful morning',
#           'Lake Hood',
#           'Bass Pro Shops',
#           '25k',
#           'Stand',
#           'Salmon Dunleavy',
#           'second',
#           '200',
#           'Hawaii',
#           'Hundreds',
#           'Northern Lights',
#           'last night',
#           'SC Alaska',
#           '8:00 pm',
#           'Begich',
#           '42.2%',
#           '42.5%'],
#  'name': 'Alaska',
#  'negHEADLINEperc': 0.12,
#  'negavgcomms': 22.833333333333332,
#  'neuHEADLINEperc': 0.6,
#  'neuavgcomms': 15.383333333333333,
#  'posHEADLINEperc': 0.28,
#  'posavgcomms': 16.107142857142858}
# 'Arizona'
# {'avgKARMAneg': 331.7,
#  'avgKARMAneu': 205.43859649122808,
#  'avgKARMApos': 215.0909090909091,
#  'density': 57.05,
#  'keys': ['NOBODY',
#           'THURSDAY',
#           'NOVEMBER 8',
#           '5 PM LOCAL TIME',
#           'this year',
#           'Arizona',
#           'Downtown Phoenix',
#           'Thanksgiving morning',
#           'Kyrsten Sinema',
#           'Senate',
#           'Martha McSally Wild',
#           'the Salt River',
#           'the day',
#           'Phoenix',
#           'Grand Canyon Gigantic',
#           'Flagstaff',
#           'Winter',
#           'the year',
#           'Havasu Falls',
#           'the Mogollon Rim',
#           'last week',
#           'BMW',
#           'Buick',
#           'Hiked Devil',
#           'Bridge',
#           'Sedona',
#           'a few months ago',
#           'Pine',
#           'PSA',
#           'roughly 18,000',
#           'Pima County',
#           'Friday',
#           'morning',
#           'AZ',
#           'this Valley of',
#           'Sun',
#           'Dawn',
#           'Phoenix Mountain',
#           '1-19',
#           'AZ Parks',
#           'South Mountain',
#           'this afternoon',
#           'Javelina',
#           '5:30am Hike',
#           'WestWing Mountain',
#           'North Peoria',
#           'Flagstaff - Calvin',
#           'Hobbes Thanksgiving',
#           'Scottsdale',
#           'Democrat',
#           'Katie Hobbs',
#           'State',
#           '150',
#           'First',
#           'Doe Mountain Taken',
#           'Monday',
#           'Jerome Grand Hotel',
#           'Montezunas’ Castle',
#           'today',
#           'Lake Pleasant',
#           'Jerome AZ',
#           'Highway 60',
#           'Show Low and Springerville',
#           'bmw',
#           'Bullhead City',
#           'Leaving Wupatki National Monument',
#           'Chandler',
#           '6 days',
#           'MARICOPA COUNTY',
#           'AZ Looking',
#           'first',
#           'Piestawa Peak',
#           'Vail',
#           'Another day',
#           'exactly 11:11 a.m.',
#           'Nov. 11',
#           'Anthem Veteran’s',
#           'five',
#           'the Armed Forces',
#           'The Great Seal',
#           'the United States',
#           'Mogollon Rim',
#           'yesterday',
#           'Aspens',
#           'this weekend',
#           'Nice BMW',
#           '7th',
#           'Ave',
#           '105-year',
#           'Tony Ranch',
#           'Haunted Canyon',
#           'Superstition Wilderness',
#           '10/27/18',
#           'Last night',
#           'Deem Hill',
#           'Pontiacycle',
#           'Lowell Observatory',
#           'Clyde Tombaugh',
#           '1930',
#           'GOP',
#           'North Dakota',
#           'Seven',
#           'Nov 4th Sunset',
#           'Hieroglyphic',
#           'Willo',
#           'last weekend',
#           'Sedona Fall',
#           'the Galiuro Wilderness',
#           '11/10/18',
#           '2',
#           'hours',
#           'Butte',
#           'the Munds Mountain Wilderness',
#           '11/3/18',
#           'Phon D Sutton Recreation Area',
#           'Tucson',
#           '100,000',
#           'Colorado River',
#           'Ferry Pass Mountain Trail',
#           'Usery Mountain Regional Park',
#           'October 2018',
#           'Love AZ',
#           'Picacho',
#           'Peak Flagstaff',
#           'early October',
#           'Montelucia',
#           'tonight',
#           'Kaibab Trail',
#           "Grand Canyon's",
#           'North Rim View',
#           'Mount Graham',
#           'Graham County Settlement',
#           'U.S. Senate',
#           'Apache County AZ',
#           '2018',
#           'late summer 2018',
#           'APS',
#           '2300',
#           'AC',
#           'AZ An',
#           'Asarco',
#           'night',
#           'San Francisco',
#           'Flagstaff Hiking',
#           'Pinnacle Peak',
#           'this morning',
#           'July 19',
#           'a long days',
#           'this evening',
#           'Culver',
#           'Creek',
#           'Potato Patch',
#           'a few weeks ago'],
#  'name': 'Arizona',
#  'negHEADLINEperc': 0.1,
#  'negavgcomms': 58.0,
#  'neuHEADLINEperc': 0.57,
#  'neuavgcomms': 23.36842105263158,
#  'posHEADLINEperc': 0.33,
#  'posavgcomms': 13.303030303030303}
# 'Arkansas'
# {'avgKARMAneg': 62.370370370370374,
#  'avgKARMAneu': 35.041666666666664,
#  'avgKARMApos': 33.88,
#  'density': 56.43,
#  'keys': [' Arkansas Dept',
#           'Buffalo River',
#           'Yall',
#           'University of Arkansas',
#           'Arkansans',
#           'Arkansas',
#           'CNN',
#           'Don Lemon',
#           'Voter',
#           'Meteor',
#           'Central Arkansas - Nov 2nd,',
#           '15-year-old',
#           'Bentonville',
#           'Eliana',
#           'Conservative Arkansas',
#           '1',
#           '4',
#           'Dashcam Captures Intense Police',
#           'Tontitown',
#           'Entergy Arkansas',
#           'two',
#           'one',
#           '2030',
#           'Pepsi',
#           'UALR',
#           'Bryant',
#           'thousands',
#           'More than 12',
#           'Medicaid',
#           'Ethics Commission Opens Investigation',
#           'Asa Hutchinson Marion Co',
#           'Patriots',
#           'Constitution',
#           'a couple months',
#           'EPA',
#           'Audio',
#           'Midterm',
#           'Years Large Group',
#           "Neo-Nazi's",
#           'Halloween',
#           'Fort Smith',
#           'State',
#           'Mickey Gates',
#           'Ballot Initiative 5',
#           'Pet',
#           'Thanksgiving',
#           'Mountain View',
#           'Election Day',
#           'China',
#           'Asa Hutchinson',
#           'Chinese',
#           'four',
#           'more than $1.4 billion',
#           'season 3',
#           'NWA',
#           'Lost Camera',
#           'Rock Loop',
#           'Looking',
#           'Miracle Medical Marijuana Program',
#           '1st',
#           'Seeking Re-Election Sues',
#           'Halt Outside Attack Ads',
#           'the United States',
#           'Donna Axum Whitworth',
#           'first',
#           'Miss America',
#           '76',
#           'Arkansas Democratic Party Raises Concerns',
#           'Three',
#           'removed more than 12,000',
#           'Monticello Subreddit Election',
#           'Oaklawn',
#           '$100m',
#           'Watch Tom Cotton',
#           'Veterans Day',
#           'Republicans',
#           'Russellville',
#           'Bird',
#           'Ark. Political Party',
#           'Child Porn',
#           'Arkansan',
#           'HBO',
#           "Bangin' in Little Rock",
#           'AR',
#           'The Arkansas Poll 2018',
#           'Arkansas Man Describes Escaping',
#           'Garage Fire Walmart',
#           '570',
#           'Voting Machines',
#           'Yesterday ELECTION DAY 2018:',
#           '$14 million',
#           'El Dorado',
#           'more than $2.7 million',
#           'Bill',
#           'Eureka Springs Election Protection',
#           '2018',
#           'Turkish',
#           'Greek',
#           'A Good Gamble',
#           'Boy Erased',
#           'Arkansan Garrand Conley',
#           'Two',
#           'Democratic',
#           "Eastern Europe'",
#           'Nazis',
#           'Little Rock',
#           'Heard Much on',
#           'the News Question',
#           'Eagle Rock Loop',
#           'Pet Adoption Event',
#           'Springdale',
#           'tomorrow',
#           'next year',
#           'Southern AR',
#           'New Details',
#           'Child Porn Arrest',
#           'AR Political Party',
#           'Hot Springs',
#           'the summer',
#           'Casino Expansion Revealed at',
#           'Oaklawn Racetrack',
#           'Best Live Shot',
#           'Arkansas Steel Fall Foliage Suggestions',
#           'Arkansas State Senate',
#           'the “Arkansas”',
#           'Odd',
#           'Tyson Foods',
#           'Aggressive Approach',
#           '24 hours',
#           'I-40',
#           'ArDOT',
#           'winter',
#           'Best',
#           'Little Rock or Bentonville',
#           'Hill & Clarke Tucker',
#           'Little Rock Store',
#           'Apparent Blackface Photo Ozark National Forrest Potential',
#           'Daniel Gafford',
#           '27',
#           'PTS 12 REBS 3 BLKS | Arkansas Razorbacks vs',
#           "Indiana Bentonville's",
#           '$12M Infusion',
#           'New York'],
#  'name': 'Arkansas',
#  'negHEADLINEperc': 0.27,
#  'negavgcomms': 18.37037037037037,
#  'neuHEADLINEperc': 0.48,
#  'neuavgcomms': 15.958333333333334,
#  'posHEADLINEperc': 0.25,
#  'posavgcomms': 16.96}
# 'California'
# {'avgKARMAneg': 444.8333333333333,
#  'avgKARMAneu': 629.3846153846154,
#  'avgKARMApos': 321.8421052631579,
#  'density': 241.7,
#  'keys': ['Only 39%',
#           'California',
#           'The Dialysis Industry Is Spending',
#           '$111 Million',
#           "Trump's",
#           'San Francisco',
#           'LA',
#           'San Jose',
#           '1st',
#           '2nd',
#           '3rd',
#           'US',
#           'California GOP Assembly',
#           'Kristin Olsen',
#           'GOP',
#           'Orange County',
#           'Republicans',
#           'Congress',
#           'next year',
#           'Democrat',
#           'Katie Porter',
#           'U.S. House',
#           'Reagan',
#           'Mimi Walters',
#           '261',
#           'DOT',
#           'Traffic Gray',
#           'U.S.',
#           'Trump administration',
#           'Borderline Bar',
#           'Thousand Oaks',
#           '87',
#           'almost 500',
#           'PSA',
#           'Gavin Newsom',
#           'Trump.',
#           '110',
#           'Halloween',
#           'the 25th year',
#           'Operation Boo',
#           'Californians',
#           'MoveOn',
#           'Rapid Response',
#           '11/8',
#           '5pm',
#           '19.7 million',
#           '78.1 percent',
#           '25.2 million',
#           '21',
#           'States',
#           '5',
#           'Cities Demand Trump Administration',
#           'Stricter Fuel Efficiency Guidelines Carson Mansion',
#           'Eureka Analysis',
#           'more than half a billion',
#           '20,000',
#           'one',
#           '24,364-acre',
#           'Point Conception',
#           'the Bixby Ranch',
#           'Camp Fire',
#           'Butte County',
#           'Trump Wants',
#           "Kill California's",
#           'GM',
#           'Camp',
#           'California Vote',
#           'Trump blames',
#           'at least 1,000',
#           'Northern California',
#           'Paradise',
#           'Chico',
#           'NE',
#           'Sacramento Valley',
#           'FEMA',
#           'Hetch Hetchy',
#           '1909',
#           '— US National Park Service',
#           'America',
#           'Republican',
#           "David Valadao's",
#           '447',
#           'Central Valley House',
#           'election year',
#           'FDA',
#           'E.',
#           'Southern California',
#           'Los Angeles County',
#           '100',
#           '93-year-old',
#           'Thurmond',
#           'Tuck',
#           'Fact Check',
#           'Jerry Brown Veto',
#           'Wildfire Management',
#           'Brown',
#           'CA',
#           'Rains',
#           '4.5 million',
#           'The LA Times Fails',
#           'Cover Major Court Victory for High-Speed Rail Inmate',
#           'Report',
#           'PG&E',
#           'Cisneros',
#           'House',
#           'Southern California Republicans Walters',
#           'Kim',
#           'Trump tactic',
#           'Los Angeles Times',
#           'Dana Rohrabacher',
#           'Orange County House',
#           'NorCal',
#           'Coastal Pacific Oxygen Levels',
#           'Now Plummet Once',
#           'Oregon & Washington',
#           'City of Anaheim',
#           'Disneyland California',
#           'World',
#           'Global SuperTanker',
#           'Boeing',
#           '747',
#           'the Golden State',
#           '75',
#           'K Homes Ordered',
#           'Woolsey Fire Jumps',
#           'Malibu',
#           'second',
#           'the past half-century',
#           'Eleni',
#           'Kounalakis Wins',
#           'Race Katie',
#           'House Race',
#           'Democratic',
#           'Proposition 10',
#           'the Civil War Prop 6',
#           'Senate',
#           'nine',
#           'Mike Levin',
#           'Darrell Issa',
#           'San Diego County',
#           '6',
#           'Election Megathread',
#           'The Terrifying Science Behind California’s',
#           'Massive Camp Fire',
#           '2018',
#           'California Midterm Election Results Multiple',
#           'Thousand Oaks bar Election',
#           'L.A.',
#           'D.A.',
#           'Customers Buy',
#           'Doughnut Shop',
#           'Steve Knight',
#           'Seat',
#           'Katie Hill',
#           'East Palo Alto',
#           'Gil Cisneros',
#           'Young Kim',
#           'CA-39) Audit',
#           'Denham',
#           'Modesto',
#           'San Joaquin Valley',
#           'November 2018',
#           'California Wildfire Megathread Evacuations',
#           'Hill Fire',
#           'Camarillo Springs',
#           'CSUCI',
#           'Santa Rosa Valley',
#           'Atkins',
#           'Kamala Harris',
#           'Tom Steyer',
#           'FBI',
#           'first',
#           '30 years',
#           'UCLA',
#           'UC',
#           'California State Parks',
#           'Thanks Military Community',
#           'Providing Free Admission',
#           '144',
#           'Parks',
#           'Monday, November 12',
#           'Harris',
#           '$2.8 trillion',
#           'Fires',
#           '— South San Francisco',
#           'Daly City',
#           'N95',
#           'One',
#           'last year',
#           'the University of California',
#           'Santa Cruz',
#           '25 centimetres',
#           '9.8',
#           'two'],
#  'name': 'California',
#  'negHEADLINEperc': 0.42,
#  'negavgcomms': 98.85714285714286,
#  'neuHEADLINEperc': 0.39,
#  'neuavgcomms': 139.02564102564102,
#  'posHEADLINEperc': 0.19,
#  'posavgcomms': 68.57894736842105}
# 'Colorado'
# {'avgKARMAneg': 324.90909090909093,
#  'avgKARMAneu': 345.0,
#  'avgKARMApos': 374.0,
#  'density': 49.33,
#  'keys': ['Boulder',
#           'this morning',
#           'Eureka',
#           'Colorado',
#           '1900',
#           'Xpost',
#           '/r',
#           'Cop Wins',
#           'Halloween Autumn',
#           'Standard Colorado',
#           'Flag',
#           'Rollins Pass',
#           'Manitou',
#           'Incline Jared Polis Projected First',
#           'Gay Man',
#           'Tom Sullivan',
#           'Aurora',
#           'GOP',
#           'House',
#           'the Rocky Mountain Wildlife Foundation',
#           'Guffey',
#           'Ohio',
#           'a week camping',
#           'these two a couple weeks ago',
#           'a few days ago',
#           'Beautiful Breck',
#           'An Autumnal day',
#           '74',
#           'CLEAR',
#           'Colorado Low Emission Automobile Regulations',
#           'Garden Of The Gods',
#           'Thanksgiving Colorado',
#           '33%',
#           'Ds',
#           'Rs Trump',
#           'Colorado Republicans’',
#           'America',
#           'Denver',
#           'Pittsburgh',
#           'Jewish',
#           'Amazon',
#           '15/hr',
#           'Three',
#           'Coloradans',
#           '1',
#           '3',
#           'Trump Administration Backs',
#           '2018',
#           'Republicans',
#           'Goodmorning',
#           'Colorado Land',
#           'the Ute Indian Tribe',
#           'Lake Dillon',
#           'Instagram Bobcat',
#           'Pagosa Springs',
#           'St. Mary’s',
#           'Face Jail Time',
#           "Dyeing Cancer Patient's",
#           'Vagina Purple',
#           'Joke',
#           'National Monument',
#           'Grand Junction Gardner',
#           'Rick Scott',
#           'Democrats',
#           'Florida',
#           'Hickenlooper',
#           'Woke',
#           'Durango',
#           'OC',
#           'State',
#           'Protectionist',
#           'ISP-Written',
#           'today',
#           'Declare Victory',
#           'The Flatirons',
#           'Fresh Air',
#           'Friday',
#           'Nov. 23',
#           'roughly $43,000',
#           '20,000',
#           "Boulder County's",
#           'Steamboat',
#           "Big Oil's",
#           'Plot to Conquer Colorado Firefighting',
#           '$130 million',
#           '40',
#           'daily',
#           'Eagle',
#           'Wine',
#           'CBD',
#           'Hemp',
#           'the Western Slope’s',
#           'MaroonBells',
#           'the Front Range',
#           'Yampa Valley Airport',
#           'Colorado Beautiful Hanging Lake',
#           'California',
#           'Pikes Peak',
#           'this summer',
#           'Wheeler Geologic',
#           'Mineral County',
#           '3.2',
#           'Millennials',
#           'Pew Research',
#           'Tabernash',
#           'a few years',
#           'Arapaho Pass',
#           'Divide',
#           "Springs Cloud Factory Drone's",
#           'San Isabel National Forest',
#           'September',
#           '7:00pm',
#           'tonight',
#           '2.2 million',
#           '10%',
#           '2014',
#           'Arapahoe National Recreation Area',
#           'the Great Sand Dunes',
#           'Unfiltered Colorado',
#           'Red Rocks',
#           'the San Isabel National Forest',
#           'Monarch Pass Hiking',
#           'Pawnee',
#           'Colorado Uber',
#           '15-year-old',
#           'Jared Polis',
#           'Vail',
#           'Beaver Creek',
#           'Aspen — to',
#           '2018-19 season',
#           '14,034',
#           'the San Juans',
#           'Twin Sisters Peak',
#           'Estes Park',
#           'Whetstone Mountain',
#           'Crested Butte',
#           'this fall',
#           'The Ballad of Buster Scruggs',
#           'San Juans'],
#  'name': 'Colorado',
#  'negHEADLINEperc': 0.11,
#  'negavgcomms': 100.81818181818181,
#  'neuHEADLINEperc': 0.55,
#  'neuavgcomms': 46.78181818181818,
#  'posHEADLINEperc': 0.34,
#  'posavgcomms': 32.88235294117647}
# 'Connecticut'
# {'avgKARMAneg': 258.75,
#  'avgKARMAneu': 193.22222222222223,
#  'avgKARMApos': 235.4,
#  'density': 739.1,
#  'keys': [' Legalizing Marijuana',
#           'Jahana Hayes - the',
#           'Congress',
#           'Connecticut',
#           'Derby',
#           'CT Rapid Response Protest',
#           'tomorrow',
#           '5pm',
#           'Hartford',
#           'New Haven',
#           'CT Someone',
#           'Suicide Wings',
#           'the Dew Drop Inn',
#           'CT',
#           'TIL',
#           'Farmington',
#           'the 19th century',
#           'the "Grand Central Station',
#           'the Underground Railroad',
#           'Stefanowski',
#           '23',
#           'Uconn',
#           'last night',
#           'Bed, Bath, & Beyond Hartford',
#           'Heublein Tower',
#           "last night's",
#           'Fall',
#           'the West Hartford Reservoir',
#           'this morning',
#           'Ned',
#           'Gil Sleazy',
#           'Dave Rutigliano',
#           'Two',
#           'Middlebury',
#           'Shelton',
#           'Hartford Whalers',
#           'last week',
#           'this week',
#           'Middletown',
#           'Early evening',
#           'Collinsville',
#           '🍃',
#           'Barbara Dalio',
#           'Ned Lamont',
#           'Today',
#           '21st',
#           'Connecticut Veteran',
#           'West Hartford',
#           'Newtown Hartford',
#           'Saturday',
#           'afternoon',
#           'A week later',
#           'Civil war II',
#           'Colchester',
#           'Town Hall',
#           'Heublein Tower Landmarks of',
#           'Connecticut Art Things',
#           'yesterday',
#           'DUI',
#           'I-84',
#           'Ingalls Rink',
#           'New Haven Archeologists Discover Evidence Of Earliest',
#           'Connecticut Alright CT',
#           'Ragged Mountain',
#           'Berlin Newtown',
#           'USA Today',
#           '3rd',
#           'Oriental Garden',
#           'Wickham Park',
#           'today',
#           'Christmas',
#           'Gillette Castle',
#           'Hurley',
#           'UCONN',
#           'Iowa Looks',
#           '80%',
#           'Gov Race',
#           'Quinnipiac University Poll Finds',
#           'Murphy Holds 15-Point Lead',
#           'U.S.',
#           'Senate',
#           'Race',
#           'Crouch',
#           'Thanksgiving',
#           'Ledyard',
#           'Lamont',
#           'Channel 3',
#           'Beacon Falls',
#           'the Connecticut State Capitol',
#           'Republican',
#           'Semitic',
#           'Old Mill',
#           'November 15th',
#           'Yantic Falls',
#           'Norwich November',
#           'North Branford',
#           'Marijuana',
#           'Massachusetts',
#           'next week',
#           '22-Year-Old',
#           "Haskell Wins Incumbent Toni Boucher's",
#           'Seat New Canaan',
#           'five',
#           'election night',
#           'Pootatuck River',
#           'Sandy Hook',
#           'the next 4-8 years',
#           'New Haven Counted',
#           'Bradley Airport',
#           'Monday',
#           'Nov. 5',
#           'Boughton',
#           'Republicans',
#           '20+ years',
#           'Bob',
#           'UConn Law School',
#           'Live 2018 Midterm Election Results',
#           'Stephanowski',
#           'CT Governors',
#           'WFSB',
#           'Lose Drone',
#           'Newtown'],
#  'name': 'Connecticut',
#  'negHEADLINEperc': 0.12,
#  'negavgcomms': 118.58333333333333,
#  'neuHEADLINEperc': 0.63,
#  'neuavgcomms': 52.42857142857143,
#  'posHEADLINEperc': 0.25,
#  'posavgcomms': 46.76}
# 'Delaware'
# {'avgKARMAneg': 46.0625,
#  'avgKARMAneu': 54.564516129032256,
#  'avgKARMApos': 62.5,
#  'density': 464.3,
#  'keys': ['today',
#           'Uncle Joe',
#           'First',
#           'Wilmington',
#           'Newark',
#           'Dover',
#           'Hagley',
#           'Rt 4 every',
#           'a last minute',
#           'Scotch Walker',
#           'several years',
#           'Delaware Truth Things',
#           'Delaware',
#           'Multi Alarm Fire',
#           'Willey Farms Found',
#           'Richardson Park Wilmington',
#           'Thanksgiving',
#           'Lewes Bay',
#           'one',
#           'Woodland Beach',
#           'daily',
#           'Chapel Street',
#           'White Clay',
#           'UD',
#           'Christiana Towers',
#           'Lending A Hand',
#           'Colleen Davis',
#           'Words of Grinchdom',
#           'DNREC',
#           "Black Friday '",
#           'N.J.',
#           'Kent General',
#           'the Markell Trail',
#           'November 21, 2018',
#           'Basin',
#           '1k+ miles',
#           'Del.',
#           '1',
#           '5',
#           'Delawate',
#           'as 1st',
#           'Willey Farms',
#           'Black Friday',
#           'WSTW',
#           'Acorn Books',
#           'Smyrna',
#           'Amazon',
#           'at least $15',
#           'Maps',
#           'Dover Downs',
#           '269,000',
#           'the last three months',
#           '389,000',
#           '2018',
#           'Long Neck',
#           'tomorrow',
#           'Over 66%',
#           '500',
#           'DE',
#           'just 5',
#           'Inmate',
#           'Vaughn',
#           'second',
#           'two weeks',
#           'Division 2',
#           '100 percent',
#           'Panhandler Walgreens',
#           'Panhandling',
#           'Driver',
#           'PsBattle',
#           'Joe Biden',
#           'Xpost',
#           'Tom Carper',
#           'Lisa Blunt Rochester',
#           'Sky',
#           '️',
#           'November',
#           'Pancreatic Cancer Action Network Update',
#           'Logan House',
#           'Halloween',
#           'Loop',
#           'Claymont History',
#           '10 years ago',
#           'Brookview',
#           'Darley Green',
#           'New State',
#           'Park Dedicated',
#           'Christmas',
#           'Polar Plunge Team',
#           'Metallica',
#           'Justice',
#           '1989',
#           'Conrad School',
#           'Forest Gate Apartments',
#           'The Riverside Neighborhood',
#           'Northeast Wilmington',
#           'the 19th Purpose Built Community',
#           'the United States',
#           'DE to Die',
#           'Cape Henlopen HS',
#           'Autopsy',
#           '84th',
#           '42nd',
#           'Thoughts & Prayers',
#           'I-95 Today Middletown',
#           'New Castle County Southern Library',
#           'Hansen',
#           'Scott Walker',
#           'Sussex',
#           '95',
#           'Mall',
#           'October 2018',
#           'Dover Mall',
#           '1999',
#           'Pike Creek Shopping Center',
#           '10',
#           'the Delaware - GO',
#           'Turkey',
#           "Thanksgiving Scratch Magoo's",
#           'New Castle Store',
#           'James Madison',
#           'Ken Simpler',
#           'Record'],
#  'name': 'Delaware',
#  'negHEADLINEperc': 0.16,
#  'negavgcomms': 22.5,
#  'neuHEADLINEperc': 0.62,
#  'neuavgcomms': 27.629032258064516,
#  'posHEADLINEperc': 0.22,
#  'posavgcomms': 20.136363636363637}
# 'District of Columbia'
# {'avgKARMAneg': 316.52941176470586,
#  'avgKARMAneu': 333.4107142857143,
#  'avgKARMApos': 343.48148148148147,
#  'density': 10065,
#  'keys': ['Halloween',
#           'DC',
#           'Thursday',
#           'last night',
#           'Tonight',
#           'the White House',
#           'Rock Creek Park',
#           'today',
#           'this morning',
#           'Capitol Hill Fall Color',
#           'first',
#           'Thanksgiving',
#           'Park View Washington Capitals',
#           '19',
#           'Snow',
#           'Arlington National Cemetery',
#           'Virginia',
#           'The C&O Canal Towpath',
#           'Route 1 to',
#           'Reagan',
#           'National Metro Station',
#           'D.C.',
#           'Amazon',
#           '$1 billion',
#           'one-day',
#           'Cleveland Park Metro',
#           'THURSDAY',
#           'José Andrés',
#           'Ocasio-Cortez',
#           'HQ2 Spectacle',
#           'Yesterday',
#           'Antares',
#           'Jefferson',
#           'early this morning',
#           'Wallops Island',
#           'Va',
#           'Jefferson Memorial',
#           'a few weeks ago',
#           'Woodley Park D.C.',
#           'winter',
#           '2018-2019',
#           'three years',
#           'the WW2 Memorial',
#           'last year',
#           'Obama',
#           'Wexton',
#           'Kaine',
#           'Vietnam',
#           'the National Archives Amazon',
#           'Advanced Talks for HQ2',
#           'Northern VA Little',
#           'Michelle Obama',
#           'the National Portrait Gallery',
#           'Uptick',
#           'Traffic Fatalities',
#           'More Than 90 Intersections',
#           'DCist Fall',
#           'DC Capital Bikeshare',
#           'Election Day',
#           'Crystal City',
#           'National Landing',
#           'Frederick Douglass',
#           'Native American',
#           'centuries',
#           'Pooks Hill Road',
#           'Bethesda',
#           'Today',
#           'Senate',
#           'Candy Desk"',
#           'Daybreak',
#           'Pentagon',
#           'Amazon Chooses',
#           'New York City',
#           'Northern Virginia',
#           "Additional Headquarters Chinatown's",
#           'Fox News',
#           "Host Tucker Carlson's",
#           'DC Home Targeted',
#           'Anti-Fascist Protesters Visited National Cathedral for Veterans Day',
#           '295',
#           '45 minutes',
#           '1',
#           'Beatles',
#           'the Washington Coliseum',
#           '1964',
#           'Avoid Crafty Bastards',
#           'Pepco Urges',
#           'Bill Anyone',
#           '3, 1964',
#           '164 years',
#           'Arlington',
#           'Veterans day',
#           'Metro',
#           'GM Proposes',
#           '$2',
#           'Budget Apple Eyes Fairfax County',
#           'Amazon Someone',
#           'Union Station',
#           'early this AM',
#           'Banksy',
#           'Girl',
#           'Balloon',
#           'Matthew Shepard',
#           'Washington',
#           '20 years',
#           'Bowser',
#           'Mumbo',
#           'The Mayor',
#           'DuPont Circle DC',
#           '123',
#           'tonight',
#           'Adas',
#           'Israel',
#           '2 day',
#           'a week',
#           'Thanksgiving morning',
#           'PSA',
#           '1-800-273-8255',
#           'National Cathedral',
#           'Tuesday',
#           'night',
#           'Noma Rainbow',
#           'U.S.',
#           'Capitol on',
#           'Election Day 2018',
#           'Bentleys',
#           'a foggy morning',
#           'Arboretum',
#           'weekend',
#           'House',
#           'Rooftop dog',
#           'Columbia Heights',
#           'Legal',
#           'Congress Shifts',
#           'Instagram Rock Creek Park',
#           'Autumn',
#           'SB GW Parkway',
#           'Rt 1',
#           'Reagan National',
#           'Barnard Elementary',
#           'Winter Weather Forecast',
#           'DMV',
#           'The Brunswick MARC',
#           'Tenley',
#           'Space Lovers',
#           'AU',
#           'this past weekend',
#           'Minor Threat',
#           'Kennedy Center',
#           'Last Night',
#           'HQ2'],
#  'name': 'District of Columbia',
#  'negHEADLINEperc': 0.17,
#  'negavgcomms': 102.05882352941177,
#  'neuHEADLINEperc': 0.56,
#  'neuavgcomms': 52.035714285714285,
#  'posHEADLINEperc': 0.27,
#  'posavgcomms': 48.55555555555556}
# 'Florida'
# {'avgKARMAneg': 360.03333333333336,
#  'avgKARMAneu': 328.22222222222223,
#  'avgKARMApos': 484.28,
#  'density': 353.4,
#  'keys': ['Nutshell',
#           'America',
#           'I-4',
#           'Rick Scott',
#           'Rocket',
#           'hundreds',
#           'Florida Neo-Nazi',
#           'KNOW',
#           'Florida',
#           'Mail',
#           'Ballot',
#           'Saturday',
#           'CRITICAL',
#           'More than 100k',
#           'One',
#           'Ballot, MWAH HA HA HA HA HAAAA',
#           'Two',
#           'MWAH HA HA',
#           'HA',
#           '30 minutes',
#           '13',
#           'Weekie Wachee',
#           'Jimmy Buffett',
#           'two years',
#           'Floridians',
#           'Andrew Gillum',
#           'Bill Nelson',
#           'Nelson Campaign',
#           'Stop Rejection Of Ballots',
#           'Voter Signatures',
#           'Vote DeSantis',
#           'Reddit',
#           'today',
#           '“Victims Rights” Amendment 6',
#           'Bill Nelson F',
#           'Circus World',
#           'June 15, 1985',
#           'Haines City',
#           '1974',
#           '1986',
#           'Boardwalk and Baseball',
#           '1987',
#           '1990',
#           'Footage Emerges Of Teenage',
#           'Gillum Voicing Florida Voter Suppression',
#           '1.5 million',
#           'Amendment 4 Marc E. Elias',
#           'Gov Scott’s',
#           'Broward County',
#           'DENIED',
#           'Brenda Snipes',
#           'Broward',
#           'two',
#           'South Florida',
#           'Senate',
#           'Nice Tallahassee',
#           'Yoga Shooter',
#           'Who Railed Against Women',
#           'RECOUNT',
#           'FLORIDA SENATE RACE League of Women Voters',
#           'Key West',
#           '1910',
#           'Keys Library',
#           "Rick Scott's",
#           'First',
#           'yesterday',
#           'Ron DeSantis',
#           'Andrew Gillum BREAKING:',
#           'THURSDAY',
#           'NOVEMBER 8',
#           '5 PM LOCAL TIME',
#           'Gillum-DeSantis',
#           'CBS',
#           'Bill Nelson-Rick Scott',
#           'Ron DeSantis Picture',
#           'Anclote Key',
#           'Cesar Sayoc',
#           'Andrew Gillum Gains 1 Vote',
#           'one',
#           'US',
#           'Gillum Concedes',
#           'Turnpike',
#           'House',
#           'Red Tide',
#           'Lake Okeechobee’s',
#           'Ron DeSantis Spotted',
#           'Boynton Beach',
#           'the Sunshine State',
#           'DeSantis',
#           'Scott',
#           'MAGAvan',
#           'MAGAbomber',
#           'SAT',
#           'Saw Andrew Gillum',
#           'the University of Florida Today Tallahassee',
#           'Fla.',
#           'AP',
#           'U.S. Senate',
#           'Trump',
#           'Republican',
#           'democrat',
#           'Cocoa Beach Pier Nikki Fried',
#           'Trick',
#           'Hurricane Michael Broward',
#           'Deadline',
#           'Thursday',
#           '700,000',
#           '5 p.m.',
#           'Rainy day',
#           'St. John’s River',
#           'this year',
#           'Veterans',
#           'every day',
#           'Tens of thousands',
#           'Lost Bird',
#           'Florida county',
#           '10-year-old',
#           '$65 million',
#           'Three',
#           'Walmart Shooting',
#           'Coconut Creek',
#           'Cypress',
#           'Alafia',
#           '18 years later',
#           'Vote Gillum',
#           'Electile Dysfunction',
#           'Panglican',
#           'Sheriff',
#           'Parkland',
#           'first',
#           'Rick Scott Stole',
#           'Florida Machine',
#           '150,000',
#           'Dozens',
#           'Miami',
#           'Halloween',
#           'Pam Bondi',
#           'Florida Senate',
#           'Rick Scott Amendment',
#           '6',
#           'the Great State',
#           'Democrat'],
#  'name': 'Florida',
#  'negHEADLINEperc': 0.3,
#  'negavgcomms': 93.03333333333333,
#  'neuHEADLINEperc': 0.45,
#  'neuavgcomms': 103.91111111111111,
#  'posHEADLINEperc': 0.25,
#  'posavgcomms': 86.36}
# 'Georgia'
# {'avgKARMAneg': 85.3125,
#  'avgKARMAneu': 75.77358490566037,
#  'avgKARMApos': 86.80645161290323,
#  'density': 169.5,
#  'keys': ['Georgia',
#           'Amicalola Falls',
#           'yesterday',
#           'Brian Kemp',
#           'Black Panthers',
#           'Abrams',
#           'mosques',
#           'Orders Georgia',
#           'Reveal Tally',
#           'GEORGIA',
#           'FRIDAY END-OF-DAY',
#           'December 4th',
#           'the Runoff Election',
#           'State',
#           'GOP',
#           'Karen Handel',
#           'Lucy McBath',
#           'Georgia 6th District',
#           'AT',
#           'Amicolola Falls',
#           'Voting Day',
#           '340,000',
#           '5 years',
#           'No.1',
#           'sixth',
#           'Over one million',
#           'Limousine Rides',
#           'Atlanta',
#           'Carrollton and Riverdale Operation Vanilla Gorilla',
#           '43',
#           'two',
#           'Hollywood',
#           'Democrats',
#           'Georgians',
#           'Delta',
#           'Republicans',
#           'more than 3,000',
#           'UK',
#           'four years',
#           'American',
#           '3 months',
#           'Libertarian',
#           'John Barrow',
#           'Democratic',
#           'Good Morning',
#           'Trump tariffs',
#           'US',
#           '3 years',
#           'Barack Obama',
#           'Stacy Abrams',
#           'A foggy morning',
#           'Stacey Abrams',
#           'Deep South',
#           'Awkward Turn',
#           'State’s Office Will Investigate Missing Absentee Ballots',
#           'Oprah Winfrey',
#           'Kemp',
#           'Weeks',
#           'roughly 1,000',
#           'Chick-fil-A',
#           '" Jon Bridges, Chick-fil-',
#           'five',
#           'the Etowah River',
#           'Thanksgiving',
#           'GA',
#           'The Latest: Voting hours',
#           'Gwinnett County',
#           'elections.sos.ga.gov',
#           'Texas',
#           'Georgia Jacks River',
#           'Murray County',
#           'Trump',
#           'Learn',
#           'Michael',
#           'SNAP',
#           '23',
#           'Sec',
#           'Democratic Party of GA Fyi',
#           'today',
#           '5pm',
#           'North Georgia',
#           'Hundreds',
#           'Voting Machines Locked',
#           'Warehouses',
#           'Election Day',
#           'Targets Oprah',
#           'Candidate Stacey Abrams',
#           'Racist Robocalls Funk Heritage Center',
#           'Native American',
#           '2018',
#           'Savannah',
#           'Grovetown',
#           'Gwinnett Certifies',
#           '5th',
#           '419',
#           'Macon',
#           'next Sunday',
#           'Kemp Go Stacy',
#           'Hurricane Michael Power Outage Timelapse',
#           'High Falls State Park - Hiking & Exploration',
#           'Runoff',
#           'Robyn Crittenden',
#           'first',
#           'African',
#           'Vote Save America',
#           'Ammendments',
#           'next Tuesday',
#           'The Etowah River',
#           'FOUR',
#           'up to 9',
#           'Pine West',
#           'South Carolina',
#           'Augusta',
#           'Athens',
#           'Griffin',
#           "Stacey Abrams'",
#           'Voting Records Report',
#           'next weekend',
#           'Veterans Day',
#           'Georgian',
#           'Moina Michael',
#           'Walton County',
#           'WWI',
#           'Christopher Lindner',
#           'ATL',
#           'Election Megathread',
#           'Obama',
#           'GEORGIA HIGH SCHOOL BAND',
#           'Voter Suppression',
#           'Georgia HS',
#           'Last weekend',
#           'Divine Felines',
#           'Egypt',
#           'the Carlos Museum Emory University',
#           'tomorrow',
#           'a 2 hour',
#           'James H Floyd State Park - Hiking & Exploration',
#           'the Georgia GOP',
#           'week',
#           'Columbus',
#           'Etowah River',
#           'nine',
#           'Run',
#           'Dec 4',
#           'The Rules Of This'],
#  'name': 'Georgia',
#  'negHEADLINEperc': 0.16,
#  'negavgcomms': 26.3125,
#  'neuHEADLINEperc': 0.53,
#  'neuavgcomms': 40.9811320754717,
#  'posHEADLINEperc': 0.31,
#  'posavgcomms': 32.354838709677416}
# 'Hawaii'
# {'avgKARMAneg': 92.05882352941177,
#  'avgKARMAneu': 130.64583333333334,
#  'avgKARMApos': 132.11428571428573,
#  'density': 214.1,
#  'keys': ['Halloween',
#           'Waikiki',
#           'second',
#           'North Shore Keiki',
#           'Longs',
#           'dusk Hawaii',
#           'Hilo Donald Trump',
#           'Saudi Arabia’s',
#           'Democratic',
#           'Tulsi Gabbard',
#           'Khashoggi',
#           'Hrrrrajahhhh 🤙 Hawaiian Supreme Court',
#           'Approves',
#           'Telescope',
#           'Mauna Kea',
#           'Kauai TIL',
#           'WWII',
#           'KIA',
#           'Moilili',
#           'tonight',
#           'Barry',
#           'Barack Obama',
#           '5th',
#           'Punahou',
#           '1972',
#           'First',
#           'Rapa Nui',
#           'Bishop Museum',
#           '15',
#           'the next three years',
#           'Haleiwa',
#           'O’ahu',
#           'Duke Kahanamoku',
#           'Hawaiian',
#           'Aug. 11, 1933',
#           'Los Angeles',
#           'last night',
#           'TON',
#           'Lanes',
#           'Tomorrow',
#           'nearly 2,900 acres',
#           'Central Oahu',
#           'VOTE Went',
#           'yesterday',
#           'the Cat Sanctuary',
#           '614',
#           'October',
#           'The Big Island',
#           'the Big Island of Hawai`i',
#           'Bill Gates',
#           'Hawaii',
#           'Magnum',
#           'Waimanlo yesterday',
#           'Aloha',
#           'Friday',
#           'Punaluu',
#           '2015',
#           'Kauai',
#           'the Delta SkyMiles',
#           'every year',
#           'HawaiiPolitics',
#           'The World Loses A Top Coral Scientist',
#           'The University of Hawaii',
#           'Cyril Pahinui',
#           'Saturday',
#           'the Queen’s Medical Center',
#           '6 p.m.',
#           'the age of 68',
#           'the Hawaii Cat Cafe',
#           'Caturday',
#           '82 tons',
#           'Northwestern Hawaiian',
#           'Pacific',
#           '1916',
#           'Chicago',
#           'the Palmyra Atoll',
#           'Adamless Eden',
#           'The Hawaiʻi Ant Lab Wins Award',
#           'this holiday season',
#           'Kahuku',
#           '128',
#           'Today',
#           'Warming Up Bruno Mars',
#           'Thanksgiving',
#           'the Hawaii Community Foundation',
#           'Honolulu',
#           '1914',
#           '700 feet',
#           'Babe',
#           'Iwilei',
#           'first',
#           'four',
#           'Kuwili Street',
#           'Kirsten',
#           'Cody',
#           'a few minutes',
#           '808 CLEANUPS PARK RESTORATION',
#           'Kuilei Cliffs Beach Park Woman Charged',
#           'Death of Hawaii Theater Actress',
#           "Ann Miles' Toddler",
#           'Lilly Geyer',
#           '3-year-old',
#           'Finley Boyle',
#           '41',
#           'Dec. 3, 2013',
#           'Longboarding Wizard today',
#           'Warner Bros. Pictures',
#           'Aquaman',
#           "Ko'ula",
#           'Kakaako',
#           'Ward Theaters',
#           'Pisonia',
#           'Palmyra Atoll',
#           '1917',
#           'Hapuna Beach',
#           'Ōlelo Hawaiʻi',
#           'all day',
#           'Bright',
#           'Rainy day',
#           'Kailua',
#           '4',
#           'GOP',
#           'Marissa Kerns',
#           'Bank of Hawaii',
#           'Craigslist',
#           'Rooms',
#           'one day',
#           'Guy Hagi',
#           'West Hawaii',
#           'Haleakala National Park',
#           'this Saturday',
#           'Waele',
#           'Haleakala',
#           'the first and third Saturday of each month',
#           'Stolen Ukulele',
#           '25th',
#           'Iz',
#           'Facing Future',
#           'Kaniela',
#           'Ing" Honolulu Zoo\'s',
#           'Japanese',
#           'Giant Salamanders',
#           'Japan',
#           'META',
#           'Photos',
#           '/r/Hawaii Hotel',
#           'Hawaii News',
#           'the “Harry Potter” Books',
#           'the Hawaiian Language',
#           'Oahu',
#           'One',
#           'Maile Shimabukuro',
#           'Los Angeles Rams',
#           'NFL',
#           'next year',
#           'MLM/Cult/Pyramid',
#           'Board of Land and Natural Resources',
#           'the Kahala Hotel &Resort',
#           'Hale’iwa',
#           'Kokua Market'],
#  'name': 'Hawaii',
#  'negHEADLINEperc': 0.17,
#  'negavgcomms': 36.23529411764706,
#  'neuHEADLINEperc': 0.48,
#  'neuavgcomms': 31.895833333333332,
#  'posHEADLINEperc': 0.35,
#  'posavgcomms': 20.771428571428572}
# 'Idaho'
# {'avgKARMAneg': 18.23076923076923,
#  'avgKARMAneu': 40.12698412698413,
#  'avgKARMApos': 46.523809523809526,
#  'density': 19.15,
#  'keys': ['Idaho',
#           'Sawtooths',
#           'today',
#           'morning',
#           'New England',
#           'Good Idaho',
#           'Idaho Potato',
#           'the Moon Let',
#           'Fairytale',
#           'Middleton',
#           'Latinos',
#           'Halloween',
#           'Idaho Payette Lake Come',
#           'tomorrow',
#           'Just another day',
#           'Taylor',
#           'Shelley',
#           '11/1/18',
#           'Sun Valley Area',
#           'Mexicans',
#           'Halloween Happy Thanksgiving!',
#           'Otter',
#           'Medicaid',
#           'Lewiston Woman',
#           'Arrested',
#           '60 Pounds',
#           'Meth',
#           '2 Pounds of Heroin',
#           'California/Mexico Border Moments',
#           'Pocy Love',
#           '1893',
#           'Rexburg Multiple',
#           'Moscow',
# ...
#           'Leaked Audio',
#           'Dave Brat',
#           'Paul Ryan',
#           'Republicans',
#           'Lie All the Time',
#           'The Abandoned Virginia Renaissance Festival Red',
#           'Kayaking the James River',
#           'Virginia Beach',
#           'Wednesday (Nov. 28',
#           'Norfolk',
#           'Pittsburgh',
#           'VA',
#           'VA Sending',
#           'Last minute',
#           '81',
#           'Beer Industry Continues to Grow Speeding Ticket',
#           '19',
#           "Katelin Aken's",
#           'Reckless Driving:',
#           'TIL',
#           'Bermuda',
#           'Virginia Debate',
#           'Supreme Court',
#           'Solar Car',
#           'STEM',
#           'Two',
#           '1950s',
#           'Dominion Energy Closes Green Bonds',
#           '574',
#           'MW Of Solar - Solar Industry',
#           'Swamp Cancer'],
#  'name': 'Virginia',
#  'negHEADLINEperc': 0.17,
#  'negavgcomms': 20.705882352941178,
#  'neuHEADLINEperc': 0.53,
#  'neuavgcomms': 15.88679245283019,
#  'posHEADLINEperc': 0.3,
#  'posavgcomms': 14.6}
# 'Washington'
# {'avgKARMAneg': 70.52380952380952,
#  'avgKARMAneu': 113.87878787878788,
#  'avgKARMApos': 87.0,
#  'density': 102.6,
#  'keys': ['Washington',
#           'Washington State Flag',
#           'Spokane',
#           'Yakama Nation',
#           'U.S. Supreme Court',
#           'Lake Chelan Timelapse Port Townsend',
#           'Historic Town',
#           'the Olympic Peninsula Mount Shuksan',
#           '- Hoquiam',
#           'North Cascades',
#           'Another typical morning',
#           'Dosewallips State Park Big Oil Scammed Washington Consumers',
#           'Oldest Apple',
#           'Tree',
#           'WA',
#           'last weekend',
#           'New Dungeness Lighthouse',
#           'Mt. Baker',
#           'this morning',
#           'Snow Lake',
#           'only 5',
#           'over 50%',
#           'Mike Leach’s',
#           'Obama',
#           'WSU',
#           '$1.6 million',
#           'Eightmile Lake',
#           'second',
#           'Ruston',
#           "The Northwest's Largest River Restoration -- Project",
#           'more than 6,000',
#           'Central Washington',
#           'Snoqualmie Falls',
#           'U.S',
#           '1',
#           'Comcast',
#           'Snoqualmie Casino',
#           'WSDOT',
#           '$1M',
#           'SR 18 State Rep',
#           'FBI',
#           'Switzerland',
#           'Camp Casey Nooksack Falls',
#           '10/20',
#           'Western Washington',
#           'Poo Poo',
#           'Point - Chirico Trail',
#           'First',
#           'Carbon Fee',
#           'Monday November 26, 2018',
#           'Dash',
#           'Matt Shea',
#           'Biblical Basis for War’',
#           'Largest Solar Plant',
#           '28',
#           'MW-DC',
#           'Adams County',
#           'two',
#           'Dry',
#           'the last 10-15 years',
#           'Hikes',
#           'Olympic',
#           'Ruby Beach',
#           'WA Coastal Pacific Oxygen Levels',
#           'Now Plummet',
#           'California',
#           'Oregon & Washington',
#           'Chewelah',
#           'WA today',
#           'Picnic Point Park',
#           'Mukilteo Farmers',
#           'Air Force',
#           'Airway Heights',
#           '150',
#           'Western State Hospital',
#           'Pullman',
#           '10/24',
#           'Lawmaker',
#           '2',
#           'Facebook',
#           'Thanksgiving',
#           'Lake Washington',
#           'Mount Rainier',
#           'OC',
#           'Seattle',
#           'first',
#           '4 years',
#           'Fort Vancouver',
#           'A Historic Trade Post Of The Pacific Northwest Hanford',
#           'German',
#           'Glacier Peak',
#           'Silverdale Washington Defense',
#           'James Mattis',
#           'Joseph Middle School',
#           'Richland',
#           'Could Approve',
#           'U.S.',
#           'DST',
#           '1631',
#           'about half',
#           'the North Cascades State',
#           'SC Media',
#           '‘Holy Army’',
#           '1639',
#           'Andrew Saturn',
#           'Thurston County',
#           'WA)',
#           'AMA',
#           'THE LAST DAY',
#           'VOTE',
#           'Snohomish County',
#           'King County',
#           'Happens',
#           '4th',
#           'Lowest Utilities Bills',
#           '2018',
#           '369',
#           'Staircase Rapids Trail',
#           'Earth',
#           'ThatNWBus',
#           'Washtucna',
#           'Shoreline',
#           'Des Moines',
#           'Wa',
#           'Washington Voters Could Make History',
#           'Yesterday',
#           'Mt. Townsend',
#           '8th',
#           'Vancouver',
#           'Bow',
#           'Arrow',
#           'Jesus',
#           'Instagram',
#           'ALEC',
#           'Washington State Chair',
#           'Circulating Holy War Manual',
#           'THC',
#           'Wolf',
#           'Washington General',
#           'Jan 15 2019',
#           'Shawn Vestal',
#           'Mt. Rainer National Park',
#           'Circa',
#           'Kim Wyman Equivocates',
#           '"Voter Fraud"',
#           'Uses',
#           'Voter Suppression Sunset',
#           'Newcastle Beach Park',
#           'Shannon Ridge',
#           'this weekend',
#           '4.3 percent',
#           'The West 2',
#           'Wolf Kills Authorized',
#           'four',
#           'one',
#           'six',
#           'another this past fall',
#           'Geoduck Lawsuit',
#           'Fairchild Air Force',
#           'Further Loosen',
#           'Democrats',
#           'Republicans',
#           'Trade',
#           'Trump',
#           'Democratic',
#           'Republican',
#           'Anderson',
#           'Anderson Hay',
#           'Grain Co.',
#           'Ellensburg'],
#  'name': 'Washington',
#  'negHEADLINEperc': 0.21,
#  'negavgcomms': 41.95238095238095,
#  'neuHEADLINEperc': 0.66,
#  'neuavgcomms': 18.106060606060606,
#  'posHEADLINEperc': 0.13,
#  'posavgcomms': 12.923076923076923}
# 'West Virginia'
# {'avgKARMAneg': 52.285714285714285,
#  'avgKARMAneu': 64.03125,
#  'avgKARMApos': 68.24137931034483,
#  'density': 77.06,
#  'keys': ['a cloudy day',
#           'Charleston',
#           '76',
#           'Morgantown',
#           'South Charleston Gamestop',
#           'WVU',
#           'Almost Heaven Me',
#           'New River Gorge',
#           'Wednesday',
#           '10/10',
#           'West Virginia',
#           'a nice weekend',
#           'Long Point',
#           'Fayetteville',
#           'Spruce Knob - 11/11/18',
#           '2 dozen',
#           'Thanksgiving',
#           'WV',
#           'today',
#           'Seneca Rocks - 11/11/18',
#           'Robert F. Kennedy',
#           'Bluefield West',
#           'Virginia',
#           '1960',
#           'Art Deco',
#           'Amtrak',
#           '1946',
#           'Spruce Knob',
#           'the other day',
#           'Blackwater Falls',
#           '11/7/2018',
#           'Seneca',
#           'Rocks State',
#           'Seneca Rock',
#           'One',
#           'this day',
#           'Thomas, WV',
#           'VA',
#           'KY',
#           'SC',
#           'NC',
#           'TN',
#           'the year',
#           'Bethesda',
#           'CBS',
#           'Sunday Morning Spotted',
#           'Rt 42',
#           'Black Water Falls',
#           'all seasons of the year',
#           'last week',
#           'more than 1,700',
#           'Kanawha County Trick-or-Treating',
#           'Elk Garden',
#           'W.V.',
#           'tonight',
#           'Winter wonderland-',
#           'Black Water Falls State Park',
#           'Babcock State Park',
#           "Vault Dweller's",
#           'Bickle Knob',
#           '” ~ Buddha Turkey Spur Overlook We got',
#           'Tim Irr',
#           'Spencer WV',
#           'WVU Rockefeller Neuroscience',
#           'first',
#           'Waterfall',
#           '50 years ago',
#           'the Farmington Mine Disaster',
#           "Blue Parrot Gentleman's",
#           'Club',
#           'Enough Drugs',
#           'Kill 300,000',
#           'West Virginia & Ohio Tudors Biscuit World',
#           'Ohio',
#           'West',
#           'Charleston Intoxicated',
#           'Milton John & Johnny',
#           'Roads Deckers Creek',
#           'Logan',
#           'Stonecoal Lake - one',
#           'Corridor H',
#           '911',
#           'Greek',
#           'WVU Old',
#           'Trick',
#           'Fairmont',
#           '2018',
#           'VT',
#           'Woodburn Circle',
#           '10 MORE HOURS',
#           'Washingtonian',
#           'Seattle',
#           'Dwight',
#           'Andy',
#           'The Office)',
#           'one',
#           '"Take Me Home, Country Roads',
#           'Hughes River Wildlife Management Area - Walker',
#           'WV Economic',
#           'I-77 Exit 66 Mahan',
#           'Thousands',
#           'Ice Ice Baby Night Time View of Morgantown',
#           'the Fusion Japanese Steakhouse',
#           'Folklore',
#           'West Virginia Snow',
#           'WV Store',
#           'Beta',
#           '7th',
#           'NRA',
#           'Weekly Classifieds and Events Thread - October 31, 2018 Storms',
#           'This Appalachian',
#           'Need Them',
#           'Harrison',
#           'Marion',
#           'Taylor',
#           'Preston',
#           'Mon',
#           'HEPC',
#           'autumn',
#           'Panorama',
#           'Great CaCapon',
#           'Maryland',
#           'Winfield'],
#  'name': 'West Virginia',
#  'negHEADLINEperc': 0.07,
#  'negavgcomms': 2.2857142857142856,
#  'neuHEADLINEperc': 0.64,
#  'neuavgcomms': 8.171875,
#  'posHEADLINEperc': 0.29,
#  'posavgcomms': 6.551724137931035}
# 'Wisconsin'
# {'avgKARMAneg': 233.75,
#  'avgKARMAneu': 324.26,
#  'avgKARMApos': 293.03846153846155,
#  'density': 105.2,
#  'keys': [' Baraboo High School Students Perform Nazi Salute in Group Picture',
#           'Scott Walker Tony Freakin’ Evers',
#           'Wisconsin Ahh',
#           'Tony Evers',
#           'Scott Walker',
#           'Wisconsin',
#           'AP',
#           'Baldwin',
#           'US Senate',
#           'Vukmir',
#           'CBS',
#           'Marijuana',
#           'Vote',
#           'tomorrow',
#           'Wisco',
#           'MRW Scott Walker',
#           'Madison',
#           'Sargent',
#           'Nazi',
#           'Northern Wisconsin',
#           '6',
#           "Scott Walker's",
#           'Best',
#           'Walker',
#           'Scott',
#           'GOP',
#           'Democrat',
#           'Packers',
#           'Aaron Rodgers',
#           '$1 million',
#           'California',
#           'First',
#           'corruption:’',
#           'Foxconn',
#           'WI',
#           'Walkerville',
#           'Milwaukee',
#           '$4.1 billion',
#           'Opinion) Wisconsin Republicans Are Acting Childish',
#           'Calling For Rule Changes',
#           'Tammy Baldwin',
#           'Target',
#           '$14 Million',
#           'Koch Brothers',
#           'Their Minions Packing Coming',
#           'Photo Of Students',
#           'Wisc',
#           'School District ELECTION DAY',
#           'Newald',
#           'Chinese Workers',
#           'Colorado',
#           'a record $1.51 billion',
#           '2017',
#           '90 percent',
#           'Central Wisconsin Baraboo',
#           'Emerald Preserve Park',
#           'Oak Creek',
#           '6:42 AM',
#           'today',
#           'Obama',
#           'Michigan',
#           'Democratic',
#           'Trump on',
#           'Democrats',
#           'Medicaid Walker',
#           'Massive Blue Wave',
#           'Dirty Tricks',
#           'THURSDAY',
#           '5pm',
#           'Sessions',
#           'Milwaukee County',
#           'Burger King',
#           '8',
#           'Green Bay',
#           '25-Dec 2',
#           'Baraboo',
#           'FLIP-FLOP Walker',
#           'ACA',
#           'Pre-Existing Conditions-Walker Authorized Lawsuit',
#           'Brad Schimel',
#           'Wisconsin New Anchor',
#           'Ugly Coffee Mugs',
#           'hundreds',
#           'Breaking News:',
#           'more than 50,000',
#           "Red Line Crossed'",
#           'Thursday',
#           'Jeff Sessions',
#           '27',
#           '30 seconds',
#           'Voting',
#           'Kentucky',
#           'FTP',
#           '$2.9 billion',
#           'iPhone',
#           '3',
#           'Lyle Lanley',
#           'Hop',
#           'tonight',
#           'Multi-Generational Boondoggle Milwaukee',
#           'Two',
#           'Racine',
#           '300',
#           'nearly five years',
#           'Chinese',
#           'Republican',
#           'Maria Butina',
#           'Russia',
#           'Aleksandr Torshin',
#           'Russian',
#           'Last-minute',
#           'Body Snatcher’',
#           'Asia',
#           'Dems',
#           'Assembly',
#           'fall afternoon',
#           'Into Law',
#           'Last November',
#           'Trump: ‘',
#           'Medical Cannabis',
#           'Tony Evers Wins',
#           'Josh Kaul',
#           'Vos Considering Limiting',
#           'Duck Session Wisconsin',
#           'Virginia',
#           'New York',
#           'Amazon',
#           '$200 million',
#           '1895',
#           'Monroe County'],
#  'name': 'Wisconsin',
#  'negHEADLINEperc': 0.24,
#  'negavgcomms': 44.375,
#  'neuHEADLINEperc': 0.5,
#  'neuavgcomms': 111.54,
#  'posHEADLINEperc': 0.26,
#  'posavgcomms': 71.96153846153847}
# 'Wyoming'
# {'avgKARMAneg': 25.0,
#  'avgKARMAneu': 29.714285714285715,
#  'avgKARMApos': 37.1,
#  'density': 5.851,
#  'keys': ['Today',
#           'Jackson',
#           'Wyoming',
#           'SNOW',
#           "Johnny J's",
#           'Casper',
#           'Wind River Canyon',
#           'National Elk Refuge',
#           'this morning',
#           "the Platte River - Casper Sugar Loaf Mtn - Medicine Bow Nat'l "
#           "Forest Wyoming's",
#           'one',
#           'Wind River Range',
#           'Lander Wyoming',
#           '2',
#           '300+ megawatts',
#           'Breathtaking Photos',
#           'Peaceful Jackson Hole Valley',
#           'Dude Ranch',
#           'Days',
#           'The 1940s',
#           '307',
#           'Blue skies',
#           'UW',
#           'John Barrasso',
#           'today',
#           '70',
#           'MISSING HUNTER SOUTH OF ROCK SPRINGS',
#           'WY',
#           'Barrasso',
#           'the Teton Range',
#           "Matthew Shepard's",
#           'Washington DC',
#           'SNL',
#           'Gillette',
#           'nine',
#           'Thanksgiving',
#           '10',
#           "mm Glock '",
#           'WyoFile Breaking',
#           'The Albany County Sheriffs Office',
#           'Robert Michael',
#           'Robbie',
#           'Ramirez',
#           'Nov. 4',
#           'Nov. 4th',
#           'Laramie Look',
#           'Rawlins',
#           'Anne',
#           'Wy',
#           'Evanston City Council',
#           'Candidate Arrested on Charges of Manufacturing and Possessing Child '
#           'Pornography',
#           'Permit to Hike',
#           'Wyoming Weighs Charging',
#           'Yellowstone',
#           'I-80 Cloud Peak Wilderness Area Making Sheep Horn Bows BREAKING '
#           'NEWS:',
#           'Search & Rescue',
#           'Rock Springs Man',
#           '19',
#           'Lake Victor Gordon',
#           'Relocation',
#           'Georgoa',
#           'One',
#           'Cheyenne Seeking',
#           'Saw',
#           'the other day',
#           'National Christmas Tree',
#           'Oregon Trail',
#           'Washington',
#           'winter',
#           'Luton',
#           'Teton Cabins - Mount Moran - SeeJH.com Man',
#           'Laramie GOP',
#           'UW Football',
#           'Ft Collins',
#           '59',
#           'Liz Cheney',
#           'Republican',
#           'Sunset',
#           'last weekend',
#           'Star Valley Wyoming Webcam - SeeJH.com Possible',
#           'Douglas',
#           'Rustic Inn',
#           'Jackson Hole - SeeJH',
#           'Teton Pass Highway',
#           'December',
#           'Kansas',
#           'Oregon',
#           '4wd',
#           'Second',
#           'Northwest Wyoming Snake River Sporting Club - Club House',
#           'Wyoming Citizens Shoot Signs',
#           'NC',
#           'Laramie Emergency Sirens - 2018.11.18',
#           'Rawlins to Cheyenne)',
#           'Escaping Colorado'],
#  'name': 'Wyoming',
#  'negHEADLINEperc': 0.1686746987951807,
#  'negavgcomms': 7.428571428571429,
#  'neuHEADLINEperc': 0.5903614457831325,
#  'neuavgcomms': 9.591836734693878,
#  'posHEADLINEperc': 0.24096385542168675,
#  'posavgcomms': 6.0}
