# %%
import json
from pprint import pprint
import numpy as np
import datetime as dt
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.project_reax

# %%
# with open('state.json') as f:
states = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware', 'Florida', 'Georgia','Hawaii', 
'Idaho', 'Illinois','Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
'Mississippi', 'Missouri', 'Montana','Nebraska', 'NewHampshire', 'NewJersey', 'NewMexico', 'NewYork', 'NorthCarolina', 
'NorthDakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'RhodeIsland', 'SouthCarolina', 'SouthDakota','Tennessee', 'Texas', 
'Utah', 'Vermont', 'Virginia', 'Washington', 'WestVirginia', 'Wisconsin', 'Wyoming', "Nevada"]

# %%
city_subreddits = ['NYC', 'Seattle', 'Chicago','LosAngeles', 'Portland', 'Boston', 'Austin', 
'SanFrancisco', 'Atlanta', 'Philadelphia', 'Denver', 'Dallas', 
 'Baltimore', 'StLouis', 'BayArea', 'washingtondc', 
'twincitiessocial', 'sandiego', 'pittsburgh', 'houston', "Anchorage", "phoenix", 'Sacramento', "orlando",
 "louisville", "neworleans", "nashville", "Miami", "lasvegas", "SaltLakeCity", "phoenix"]

# %%
with open('state.json') as f:
    data = json.load(f)

# %%
city_full_lite = db.city_full_lite.find({}).sort('location')

# %%
#append cities in state and latlong

# for d in data['features']:
#     pprint(d['properties'])

    
#     for city in city_full_lite:
#         s = city['state']
#         c = city['city']
#         lat = city['latitude']
#         long = city['longitude']
        
for post in db.city_full_lite.find({"date": {"$gt": d}}).sort("author"):
# Out:
# {'CENSUSAREA': 50645.326,
#  'GEO_ID': '0400000US01',
#  'LSAD': '',
#  'NAME': 'Alabama',
#  'STATE': '01'}
# {'CENSUSAREA': 570640.95,
#  'GEO_ID': '0400000US02',
#  'LSAD': '',
#  'NAME': 'Alaska',
#  'STATE': '02'}
# {'CENSUSAREA': 113594.084,
#  'GEO_ID': '0400000US04',
#  'LSAD': '',
#  'NAME': 'Arizona',
#  'STATE': '04'}
# {'CENSUSAREA': 52035.477,
#  'GEO_ID': '0400000US05',
#  'LSAD': '',
#  'NAME': 'Arkansas',
#  'STATE': '05'}
# {'CENSUSAREA': 155779.22,
#  'GEO_ID': '0400000US06',
#  'LSAD': '',
#  'NAME': 'California',
#  'STATE': '06'}
# {'CENSUSAREA': 103641.888,
#  'GEO_ID': '0400000US08',
#  'LSAD': '',
#  'NAME': 'Colorado',
#  'STATE': '08'}
# {'CENSUSAREA': 4842.355,
#  'GEO_ID': '0400000US09',
#  'LSAD': '',
#  'NAME': 'Connecticut',
#  'STATE': '09'}
# {'CENSUSAREA': 1948.543,
#  'GEO_ID': '0400000US10',
#  'LSAD': '',
#  'NAME': 'Delaware',
#  'STATE': '10'}
# {'CENSUSAREA': 61.048,
#  'GEO_ID': '0400000US11',
#  'LSAD': '',
#  'NAME': 'District of Columbia',
# ...
